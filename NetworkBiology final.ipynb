# %% [markdown]
# ## ADVANCED CODING PROJECT:
# ##       Data Analytics in Network Biology
# #### Team members: Alessandro Ivashkevich, Andrea Magri, Alessio Attolico

# %% [markdown]
# ### Task 1 – Constructing the biomedical knowledge graph

# %%
# importing libraries
import networkx as nx
import matplotlib.pyplot as plt

# file loading
edges = open('hetionet-v1.0-edges.sif', 'r')
nodes = open('hetionet-v1.0-nodes.tsv', 'r')

# %% [markdown]
# Each node is structured in the following way:
# - ID
# - name
# - kind (or type)
#
# And edges follow this structure:
# - source node ID
# - interaction type
# - target node ID
#
# Furthermore, from a previous analysis, we have seen that the edges dataframe contained an header row, so we used the lines if line.startswith('source'):
#         continue when importing the data.

# %%
# initializing the graph
G = nx.DiGraph()

for l in nodes:
    if l.startswith('id'):
        continue
    id, name, kind = l.strip().split('\t')
    if name not in G.nodes():
        G.add_node(id, name=name, kind=kind)

for line in edges:
    if line.startswith('source'):
        continue
    source, metaedge, target = line.strip().split('\t')
    G.add_edge(source, target, type=metaedge)

print (G)
# Out:
# DiGraph with 47031 nodes and 2110272 edges

# %% [markdown]
# ### Task 2 – Analyzing the biomedical knowledge graph

# %% [markdown]
# We will now compute some metrics and analysis on the biomedical knowledge graph.
#
# 1) total number of entities for each unique kind.
# 2) total number of each unique edge type.
# 3) average in-degree and out-degree, for each type of node.

# %%
graphnodes = G.nodes()

# point 1 
n_entities = {}
for i in graphnodes:
    i = i.split("::")[0]
    if i not in n_entities:
        n_entities[i] = 1
    else:
        n_entities[i] += 1    
n_entities
print ('Total number of entities for each kind of node:')
print (n_entities)
print ()

# point 2
graphedges = G.edges(data=True)
n_edgetypes = {}
for i in graphedges:
    i = i[2]['type']
    if i not in n_edgetypes:
        n_edgetypes[i] = 1
    else:
        n_edgetypes[i] += 1
n_edgetypes
print ('Total number of each unique edge type:')
print (n_edgetypes)
print ()
 
#point 3
in_degrees = G.in_degree()
out_degrees = G.out_degree()
kind_degrees = {}
for i in graphnodes:
    kind = G.nodes[i]['kind']
    if kind not in kind_degrees:
        kind_degrees[kind] = [0,0]
    kind_degrees[kind][0] += in_degrees[i]
    kind_degrees[kind][1] += out_degrees[i]
for i in kind_degrees:
    kind_degrees[i][0] = kind_degrees[i][0]/n_entities[i]
    kind_degrees[i][1] = kind_degrees[i][1]/n_entities[i]
print ('Average in-degree and out-degree for each kind of node:')
print (kind_degrees)
print ()
# Out:
# Total number of entities for each kind of node:
# {'Anatomy': 402, 'Biological Process': 11381, 'Cellular Component': 1391, 'Compound': 1552, 'Disease': 137, 'Gene': 20945, 'Molecular Function': 2884, 'Pathway': 1822, 'Pharmacologic Class': 345, 'Side Effect': 5734, 'Symptom': 438}
#
# Total number of each unique edge type:
# {'AdG': 48324, 'AeG': 526407, 'AuG': 13098, 'CrC': 6486, 'CtD': 755, 'CbG': 11506, 'CuG': 18756, 'CcSE': 138944, 'CdG': 21102, 'CpD': 390, 'DdG': 7508, 'DpS': 3357, 'DlA': 3602, 'DrD': 543, 'DaG': 12461, 'DuG': 7731, 'GiG': 146305, 'GpCC': 73566, 'GpBP': 559504, 'GcG': 61632, 'GpMF': 97222, 'GpPW': 84372, 'Gr>G': 265672, 'PCiC': 1029}
#
# Average in-degree and out-degree for each kind of node:
# {'Anatomy': [8.960199004975124, 1462.2611940298507], 'Biological Process': [49.16123363500571, 0.0], 'Cellular Component': [52.887131560028756, 0.0], 'Compound': [4.842139175257732, 127.53801546391753], 'Disease': [12.321167883211679, 256.94890510948903], 'Gene': [54.45223203628551, 61.50742420625448], 'Molecular Function': [33.71081830790569, 0.0], 'Pathway': [46.30735455543359, 0.0], 'Pharmacologic Class': [0.0, 2.982608695652174], 'Side Effect': [24.231600976630624, 0.0], 'Symptom': [7.664383561643835, 0.0]}

# %% [markdown]
# Analysis of the results:
#
# 1) Total Number of Entities for Each Unique Kind
# 'Gene' entities are the most numerous with 20,945 instances, followed by 'Biological Process' entities at 11,381 instances, and so forth. This indicates that genes and biological processes are major focuses of the dataset, likely reflecting their central roles in biological systems.<br>
# <br>
#
# 2) Total Number of Each Unique Edge Type
# 'GpBP' (Gene processes Biological Process) edges are the most common, with 559,504 occurrences, indicating a strong emphasis on the relationships between genes and biological processes.<br>
# <br>
#
# 3) Average In-Degree and Out-Degree for Each Type of Node
# High in-degree values for 'Gene' (54.45) and 'Cellular Component' (52.89) suggest that these entities are often targets of various processes and interactions, indicating their centrality and importance in biological mechanisms. <br>
# <br>
# The high out-degree for 'Anatomy' (1462.26) and 'Disease' (256.95) indicates they are central points in the network, much like key nodes in a complex web of connections. 'Anatomy' having a high out-degree means parts of the body are often the starting points for many biological processes and interactions. Similarly, a high out-degree for 'Disease' suggests that diseases are involved in numerous pathways and can influence or be linked to a wide range of biological activities.

# %% [markdown]
# In lights of this, let's delve into computing the number of connections for each disease.

# %% [markdown]
# ### Task 2.1

# %%
# finding the 10 most connected diseases
disease_degrees = [(node, G.in_degree(node) + G.out_degree(node)) 
                   for node, data in G.nodes(data=True) if data['kind'] == 'Disease']

most_connected_diseases = sorted(disease_degrees, key=lambda x: x[1], reverse=True)

for disease, degree in most_connected_diseases[:10]:  
    print(f"Disease: {G.nodes[disease]['name']}, Total Connections: {degree}")
# Out:
# Disease: breast cancer, Total Connections: 1123
# Disease: hematologic cancer, Total Connections: 1086
# Disease: IgA glomerulonephritis, Total Connections: 948
# Disease: melanoma, Total Connections: 930
# Disease: rheumatoid arthritis, Total Connections: 880
# Disease: schizophrenia, Total Connections: 838
# Disease: Parkinson's disease, Total Connections: 789
# Disease: kidney cancer, Total Connections: 784
# Disease: hypertension, Total Connections: 768
# Disease: Alzheimer's disease, Total Connections: 761

# %%
# visualization in a bar plot of the 10 most connected diseases
top_10_diseases = most_connected_diseases[:10]

disease_names = [G.nodes[disease[0]]['name'] for disease in top_10_diseases]
total_degrees = [disease[1] for disease in top_10_diseases]

plt.figure(figsize=(10, 8))
plt.barh(disease_names, total_degrees, color='skyblue')
plt.xlabel('Total Connections')
plt.ylabel('Disease')
plt.title('Top 10 Most Connected Diseases')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Now we will compute the subgraph of “Disease” and “Symptom” and the average number of connections between a disease and a symptom.

# %%
# computing the subgraph of Diseases and Symptoms
disease_symptom_nodes = [node for node, data in G.nodes(data=True) 
                         if data['kind'] in ['Disease', 'Symptom']]
disease_symptom_subgraph = G.subgraph(disease_symptom_nodes)

total_edges = disease_symptom_subgraph.number_of_edges()
total_nodes = len(disease_symptom_nodes)
average_connections = total_edges / total_nodes if total_nodes else 0

print(f"Average number of connections between a disease and a symptom: {average_connections}")
# Out:
# Average number of connections between a disease and a symptom: 6.782608695652174

# %% [markdown]
# Now, let's visualize our subgraph

# %%
# visualizing the subgraph we have just created
plt.figure(figsize=(12, 8))

pos = nx.spring_layout(disease_symptom_subgraph)

disease_nodes = [node for node, data in disease_symptom_subgraph.nodes(data=True) if data['kind'] == 'Disease']
symptom_nodes = [node for node, data in disease_symptom_subgraph.nodes(data=True) if data['kind'] == 'Symptom']

nx.draw_networkx_nodes(disease_symptom_subgraph, pos, nodelist=disease_nodes, node_color='b', node_size=50)
nx.draw_networkx_nodes(disease_symptom_subgraph, pos, nodelist=symptom_nodes, node_color='g', node_size=50)

plt.gca().set_facecolor('white')

nx.draw_networkx_edges(disease_symptom_subgraph, pos, alpha=0.5)

plt.title('Sub-graph of Diseases and Symptoms')
plt.axis('off')
plt.show()
print (disease_symptom_subgraph)
# Out:
# DiGraph with 575 nodes and 3900 edges

# %% [markdown]
# To understand more the dynamics of the over relations in the total graph, let's visualize other subgraphs.

# %%
# plotting and visualizing the subgraph containing only Symptoms
symptom_nodes = [node for node, data in G.nodes(data=True) if data['kind'] == 'Symptom']
symptom_subgraph = G.subgraph(symptom_nodes)

plt.figure(figsize=(12, 8))

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(symptom_subgraph)
nx.draw_networkx_nodes(symptom_subgraph, pos, node_color='skyblue', node_size=50)
nx.draw_networkx_edges(symptom_subgraph, pos, alpha=0.5)
plt.title('Sub-graph of Symptoms')
plt.axis('off')
plt.show()

# %% [markdown]
# Clearly, we observe that the symptoms have no direct connections to each other.

# %% [markdown]
# Let's take a look to the subgraph of only diseases

# %%
# plotting and visualizing the sub-graph containing only Diseases
disease_nodes = [node for node, data in G.nodes(data=True) if data['kind'] == 'Disease']
disease_subgraph = G.subgraph(disease_nodes)

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(disease_subgraph)
nx.draw_networkx_nodes(disease_subgraph, pos, node_color='salmon', node_size=50)
nx.draw_networkx_edges(disease_subgraph, pos, alpha=0.5)
plt.title('Sub-graph of Diseases')
plt.axis('off')
plt.show()

# %% [markdown]
# There is a varied situation, some nodes are deeply connected to their neighbors, while others are completely disattached.

# %% [markdown]
# ### Task 2.2

# %%
# plotting and visualizing the subgraph containing only Compounds and Diseases
compound_disease_nodes = [node for node, data in G.nodes(data=True) if data['kind'] in ['Compound', 'Disease']]
compound_disease_subgraph = G.subgraph(compound_disease_nodes)

plt.figure(figsize=(12, 8))

pos = nx.spring_layout(compound_disease_subgraph)

node_colors = ['lightgreen' if G.nodes[node]['kind'] == 'Compound' else 'salmon' for node in compound_disease_subgraph.nodes]
nx.draw_networkx_nodes(compound_disease_subgraph, pos, node_color=node_colors, node_size=50)

nx.draw_networkx_edges(compound_disease_subgraph, pos, alpha=0.5)

plt.title('Sub-graph of Compounds and Diseases')
plt.axis('off')
plt.show()

# %% [markdown]
# These subgraphs, together with the sub-graph of “Disease” and “Symptom”, are essential for the determination of the values'validity obtained in the following tasks.

# %% [markdown]
# ### Task 2.3 & 2.4:

# %%
# finding IDs of the target nodes (type 1 and 2 diabetes mellitus, eye pain and blindness)
def find_node_id(graph, name):
    for node, data in graph.nodes(data=True):
        if data.get('name') == name:
            return node
    return None

type1_diabetes_id = find_node_id(G, "type 1 diabetes mellitus")
type2_diabetes_id = find_node_id(G, "type 2 diabetes mellitus")
eye_pain_id = find_node_id(G, "Eye Pain")
blindness_id = find_node_id(G, "Blindness")

(type1_diabetes_id, type2_diabetes_id, eye_pain_id, blindness_id)
# Out:
# ('Disease::DOID:9744',
#  'Disease::DOID:9352',
#  'Symptom::D058447',
#  'Side Effect::C0456909')

# %% [markdown]
# We choose to implement the Jaccard index in order to compute similarity among different diseases and symptoms. As a matter of fact, the Jaccard index indee measures similarities based on the shared neighbors of two nodes. In our context of diseases and symptoms, two diseases sharing many symptoms should have a high Jaccard similarity, which could suggest a relationship or perhaps common underlying causes between the diseases.

# %%
# defining a function to compute Jaccard similarity
def jaccard_similarity_directed(graph, node1, node2):
    successors_node1 = set(graph.successors(node1))
    successors_node2 = set(graph.successors(node2))
    predecessors_node1 = set(graph.predecessors(node1))
    predecessors_node2 = set(graph.predecessors(node2))
    
    intersection_successors = successors_node1.intersection(successors_node2)
    union_successors = successors_node1.union(successors_node2)
    intersection_predecessors = predecessors_node1.intersection(predecessors_node2)
    union_predecessors = predecessors_node1.union(predecessors_node2)
    
    intersection = intersection_successors.union(intersection_predecessors)
    union = union_successors.union(union_predecessors)
    
    jaccard_sim = len(intersection) / len(union) if union else 0
    
    return jaccard_sim

# %%
# computing Jaccard similarity between type 1 diabetes mellitus and type 2 diabetes mellitus
similarity_score_diabetes = jaccard_similarity_directed(disease_symptom_subgraph,'Disease::DOID:9744','Disease::DOID:9352')
print ('The Jaccard similarity between type 1 diabetes mellitus and type 2 diabetes mellitus is:', similarity_score_diabetes)
# Out:
# The Jaccard similarity between type 1 diabetes mellitus and type 2 diabetes mellitus is: 0.1590909090909091

# %%
# computing Jaccard similarity between eye pain and blindness
similarity_score_eye = jaccard_similarity_directed(disease_symptom_subgraph, 'Symptom::D058447', 'Symptom::D001766')
print(f"The Jaccard similarity between eye pain and blindness is: {similarity_score_eye}")

# computing jaccard similarity between eye pain and shoulder pain
similarity_score_eye_shoulder = jaccard_similarity_directed(disease_symptom_subgraph, 'Symptom::D058447', 'Symptom::D020069')
print(f"The Jaccard similarity between eye pain and shoulder pain is: {similarity_score_eye_shoulder}")
# Out:
# The Jaccard similarity between eye pain and blindness is: 0.35
# The Jaccard similarity between eye pain and shoulder pain is: 0.06666666666666667

# %% [markdown]
# Intuitively, eye pain and blindess are two strongly correlated symptoms, so their similarity value should be relatively higher than others. To confirm this thesis, we have computed the similarity of eye pain together with shoulder pain, a symptom which rarely is related with eye pain. In fact , we have observed that this last value is less 5 times more than eye pain - blindess similarity.

# %% [markdown]
# ## Task 2.5
# ### Final Challenge:
# Its essential to determine and prevent deseases, especially in old men. More than 50% of patients with lung cancer are diagnosed after the age of 65, and 30% are older than age 70. In addition, lung cancer is responsible for more deaths than colon, breast, and prostate cancer combined.

# %%
# finding all symptom names
symptom_names = [data['name'] for node, data in G.nodes(data=True) if data['kind'] == 'Symptom']
print(symptom_names)
# Out:
# ['Abdomen, Acute', 'Adie Syndrome', 'Adrenoleukodystrophy', 'Aerophagy', 'Ageusia', 'Agnosia', 'Agraphia', 'Albuminuria', 'Alcohol Amnestic Disorder', 'Alkalosis, Respiratory', 'Amblyopia', 'Amnesia', 'Amnesia, Retrograde', 'Angina Pectoris', 'Angina Pectoris, Variant', 'Angina, Unstable', 'Anomia', 'Anorexia', 'Olfaction Disorders', 'Anoxia', 'Aphasia', 'Aphasia, Broca', 'Aphasia, Wernicke', 'Aphonia', 'Apnea', 'Apraxias', 'Articulation Disorders', 'Asthenia', 'Ataxia', 'Ataxia Telangiectasia', 'Athetosis', 'Auditory Perceptual Disorders', 'Back Pain', 'Birth Weight', 'Urinary Bladder, Neurogenic', 'Blindness', 'Body Temperature Changes', 'Body Weight', 'Body Weight Changes', 'Brain Death', 'Bulimia', 'Cachexia', 'Cardiac Output, Low', 'Catalepsy', 'Cataplexy', 'Catatonia', 'Causalgia', 'Cerebellar Ataxia', 'Cerebrospinal Fluid Otorrhea', 'Cerebrospinal Fluid Rhinorrhea', 'Chest Pain', 'Cheyne-Stokes Respiration', 'Chorea', 'Choroid Hemorrhage', 'Colic', 'Color Vision Defects', 'Coma', 'Communication Disorders', 'Confusion', 'Consciousness Disorders', 'Constipation', 'Cough', 'Cri-du-Chat Syndrome', 'Cyanosis', 'De Lange Syndrome', 'Deafness', 'Hearing Loss, Sudden', 'Decerebrate State', 'Delirium', 'Diarrhea', 'Diarrhea, Infantile', 'Diplopia', 'Dizziness', 'Down Syndrome', 'Dysarthria', 'Dysgeusia', 'Dyskinesia, Drug-Induced', 'Dyslexia', 'Dyslexia, Acquired', 'Dysmenorrhea', 'Dyspepsia', 'Dyspnea', 'Dyspnea, Paroxysmal', 'Dystonia', 'Earache', 'Ecchymosis', 'Echolalia', 'Edema', 'Edema, Cardiac', 'Emaciation', 'Encopresis', 'Eructation', 'Eye Hemorrhage', 'Eye Manifestations', 'Facial Pain', 'Facial Paralysis', 'Failure to Thrive', 'Fasciculation', 'Fatigue', 'Mental Fatigue', 'Feminization', 'Fetal Hypoxia', 'Fetal Distress', 'Fetal Macrosomia', 'Fever', 'Fever of Unknown Origin', 'Flatulence', 'Flushing', 'Fragile X Syndrome', 'Gagging', 'Gerstmann Syndrome', 'Gingival Hemorrhage', 'Glossalgia', 'Halitosis', 'Hallucinations', 'Headache', 'Hearing Disorders', 'Hearing Loss, Bilateral', 'Hearing Loss, Central', 'Hearing Loss, Conductive', 'Hearing Loss, Functional', 'Hearing Loss, High-Frequency', 'Hearing Loss, Noise-Induced', 'Hearing Loss, Sensorineural', 'Heart Murmurs', 'Heartburn', 'Hematemesis', 'Hemianopsia', 'Hemiplegia', 'Hemoglobinuria', 'Hemoptysis', 'Oral Hemorrhage', 'Hiccup', 'Hirsutism', 'Hoarseness', 'Horner Syndrome', 'Huntington Disease', 'Hyperalgesia', 'Hypercapnia', 'Hyperemesis Gravidarum', 'Hyperesthesia', 'Hypergammaglobulinemia', 'Hyperkinesis', 'Hyperphagia', 'Disorders of Excessive Somnolence', 'Hyperventilation', 'Hypesthesia', 'Hyphema', 'Hypotension, Orthostatic', 'Hypothermia', 'Hypoventilation', 'Illusions', 'Sleep Initiation and Maintenance Disorders', 'Insulin Coma', 'Intermittent Claudication', 'Jaundice', 'Kearns-Sayre Syndrome', 'Menkes Kinky Hair Syndrome', 'Language Development Disorders', 'Language Disorders', 'Learning Disorders', 'Lesch-Nyhan Syndrome', 'Lipoid Proteinosis of Urbach and Wiethe', 'Memory Disorders', 'Meningism', 'Intellectual Disability', 'Monoclonal Gammopathy of Undetermined Significance', 'Motion Sickness', 'Mouth Breathing', 'Muscle Cramp', 'Muscle Hypertonia', 'Muscle Hypotonia', 'Muscle Rigidity', 'Muscle Spasticity', 'Muscular Atrophy', 'Mutism', 'Myoclonus', 'Myotonia', 'Narcolepsy', 'Nausea', 'Neuralgia', 'Neurologic Manifestations', 'Night Blindness', 'Obesity', 'Obesity, Morbid', 'Oliguria', 'Ophthalmoplegia', 'Optical Illusions', 'Oral Manifestations', 'Pain', 'Pain, Intractable', 'Pain, Postoperative', 'Pallor', 'Paralysis', 'Paraplegia', 'Paresis', 'Paresthesia', 'Perceptual Disorders', 'Phantom Limb', 'Obesity Hypoventilation Syndrome', 'Polyuria', 'Prader-Willi Syndrome', 'Presbycusis', 'Proteinuria', 'Pruritus', 'Pruritus Ani', 'Pruritus Vulvae', 'Psychomotor Agitation', 'Psychomotor Disorders', 'Psychophysiologic Disorders', 'Pupil Disorders', 'Purpura', 'Purpura, Hyperglobulinemic', 'Purpura, Schoenlein-Henoch', 'Purpura, Thrombocytopenic', 'Purp ...

# %%
# finding all the diseases related to each symptom
symptoms = [(node, data['name']) for node, data in G.nodes(data=True) if 'kind' in data and data['kind'] == "Symptom"]

diseases_per_symptom = {}

for symptom_id, symptom_name in symptoms:
    diseases_sympt = []
    predecessors = G.predecessors(symptom_id)
    for predecessor in predecessors:
        if 'name' in G.nodes[predecessor]:  
            diseases_sympt.append(G.nodes[predecessor]['name'])
    diseases_per_symptom[symptom_name] = diseases_sympt

for symptom_name, diseases_sympt in diseases_per_symptom.items():
    print(f"Diseases related to '{symptom_name}': {diseases_sympt}")
# Out:
# Diseases related to 'Abdomen, Acute': ['kidney cancer', 'acquired immunodeficiency syndrome', 'liver cancer', 'germ cell cancer', 'colon cancer', 'uterine fibroid', 'nephrolithiasis', 'adrenal gland cancer', 'celiac disease', 'anemia', 'abdominal aortic aneurysm', 'appendix cancer', 'gallbladder cancer', 'ovarian cancer', 'fallopian tube cancer', 'sarcoma', 'pancreatic cancer', 'retroperitoneal cancer', 'pancreatitis', "Crohn's disease", 'uterine cancer', 'testicular cancer', 'malignant mesothelioma', 'peritoneum cancer', 'jejunal cancer', 'duodenum cancer', 'systemic lupus erythematosus', 'ulcerative colitis', 'systemic scleroderma', 'stomach cancer', 'ileum cancer']
# Diseases related to 'Adie Syndrome': ['rheumatoid arthritis', 'migraine']
# Diseases related to 'Adrenoleukodystrophy': ['multiple sclerosis', 'bipolar disorder']
# Diseases related to 'Aerophagy': ['Gilles de la Tourette syndrome']
# Diseases related to 'Ageusia': ['peripheral nervous system neoplasm', 'multiple sclerosis', 'leprosy']
# Diseases related to 'Agnosia': ['schizophrenia', 'autistic disorder', "Alzheimer's disease", 'malignant glioma', 'brain cancer', 'epilepsy syndrome', 'Creutzfeldt-Jakob disease']
# Diseases related to 'Agraphia': ['brain cancer', "Alzheimer's disease", 'attention deficit hyperactivity disorder', 'malignant glioma', 'germ cell cancer', 'alcohol dependence', 'amyotrophic lateral sclerosis', 'multiple sclerosis']
# Diseases related to 'Albuminuria': ['type 2 diabetes mellitus', 'chronic kidney failure', 'metabolic syndrome X', 'systemic lupus erythematosus', 'hypertension', 'atherosclerosis', 'focal segmental glomerulosclerosis', 'type 1 diabetes mellitus']
# Diseases related to 'Alcohol Amnestic Disorder': ['intracranial aneurysm', 'alcohol dependence', "Alzheimer's disease"]
# Diseases related to 'Alkalosis, Respiratory': ['panic disorder', 'alcohol dependence', 'anemia', 'asthma', 'chronic kidney failure']
# Diseases related to 'Amblyopia': ['ocular cancer', 'nicotine dependence', 'age related macular degeneration', 'refractive error', 'glaucoma', 'head and neck cancer', 'alcohol dependence', 'bone cancer']
# Diseases related to 'Amnesia': ['alcohol dependence', 'meningioma', 'migraine', 'germ cell cancer', 'intracranial aneurysm', 'endogenous depression', "Alzheimer's disease", 'brain cancer', 'epilepsy syndrome', 'malignant glioma']
# Diseases related to 'Amnesia, Retrograde': ['intracranial aneurysm', "Alzheimer's disease", 'epilepsy syndrome', 'brain cancer', 'endogenous depression']
# Diseases related to 'Angina Pectoris': ['chronic kidney failure', 'hypertension', 'hypothyroidism', 'abdominal aortic aneurysm', 'Kawasaki disease', 'coronary artery disease', 'dilated cardiomyopathy', 'atherosclerosis']
# Diseases related to 'Angina Pectoris, Variant': ['migraine', 'coronary artery disease']
# Diseases related to 'Angina, Unstable': ['chronic kidney failure', 'atherosclerosis', 'coronary artery disease']
# Diseases related to 'Anomia': ["Alzheimer's disease", 'brain cancer', 'malignant glioma', "Parkinson's disease"]
# Diseases related to 'Anorexia': ['acquired immunodeficiency syndrome', 'rectum cancer', 'peritoneum cancer', 'ovarian cancer', 'liver cancer', 'cervical cancer', 'testicular cancer', 'melanoma', 'hematologic cancer', 'head and neck cancer', 'colon cancer', 'pancreatic cancer', 'malignant mesothelioma', 'esophageal cancer', 'duodenum cancer', 'uterine cancer', 'stomach cancer', 'kidney cancer', 'sarcoma', 'urinary bladder cancer', 'lung cancer', 'breast cancer', 'chronic kidney failure']
# Diseases related to 'Olfaction Disorders': ['pharynx cancer', 'schizophrenia', "Parkinson's disease", 'intracranial aneurysm', 'allergic rhinitis', 'meningioma', "Alzheimer's disease", 'head and neck cancer', 'brain cancer', 'migraine']
# Diseases related to 'Anoxia': ['pancreatic cancer', 'uterine cancer', 'atherosclerosis', 'hypertension', 'liver cancer', 'asthma', 'chronic obstructive pulmonary disease', 'chronic kidney failure', 'kidney cancer', 'anemia', 'amyotrophic lateral sclerosis', 'breast cancer', 'esophageal cancer', 'melanoma', 'cervical cancer', 'idiopathic pulmonary fibrosis', 'colon cancer', 'germ cell cancer', 'malignant glioma', 'vascular cancer', 'prostate cancer', 'head and neck cancer', 'muscle cancer', 'lung cancer', 'sarcoma']
# Diseases related to 'Aphasia': ['brain cancer', 'malignant glioma', 'autistic disorder', 'migraine', 'intracranial aneurysm', 'Creutzfeldt-Jakob disease', "Alzheimer's disease", 'epilepsy syndrome', 'multiple sclerosis', 'germ cell cancer', 'meningioma', 'endogenous depression', 'esophageal cancer']
# Diseases related to 'Aphasia, Broca': ["Alzheimer's disease", 'brain cancer', 'multiple sclerosis', 'germ cell cancer', 'malignant glioma']
# Diseases related to 'Aphasia, Wernicke': ['Creutzfeldt-Jakob disease', 'epilepsy syndrome', 'brain cancer', 'schizophrenia', "Alzheimer's disease"]
# Diseases related to 'Aphonia': ['larynx cancer', 'head and neck cancer', 'esophageal cancer']
# Diseases related to 'Apnea': ['asthma', 'anemia', 'epilepsy syndrome', 'tracheal cancer', 'brain cancer']
# Diseases related to 'Apraxias': ['germ cell cancer', 'autistic disorder', 'attention deficit hyperactivity disorder', "Parkinson's disease", 'multiple sclerosis', "Alzheimer's disease", 'Creutzfeldt-Jakob disease', 'malignant glioma', 'brain cancer']
# Diseases related to 'Articulation Disorders': ['head and neck cancer', 'cleft lip', 'pharynx cancer', "Parkinson's disease", 'attention deficit hyperactivity disorder', 'amyotrophic lateral sclerosis']
# Diseases related to 'Asthenia': ['breast cancer', 'endogenous depression', 'hypothyroidism', 'anemia', 'lung cancer', 'schizophrenia', 'kidney cancer', 'alcohol dependence', 'peritoneum cancer', 'uterine fibroid', 'osteoporosis', 'stomach cancer', 'bipolar disorder']
# Diseases related to 'Ataxia': ['germ cell cancer', 'alcohol dependence', 'epilepsy syndrome', "Parkinson's disease", 'spinal cancer', 'multiple sclerosis', 'Creutzfeldt-Jakob disease', 'hypothyroidism', 'celiac disease', 'meningioma', 'brain cancer', 'amyotrophic lateral sclerosis', 'rheumatoid arthritis', 'malignant glioma', 'autistic disorder', 'migraine']
# Diseases related to 'Ataxia Telangiectasia': ['head and neck cancer', 'skin cancer', 'ovarian cancer', 'germ cell cancer', 'anemia', 'ocular cancer', 'thymus cancer', 'malignant glioma', 'vitiligo', 'stomach cancer', 'liver cancer', 'thyroid cancer', 'breast cancer']
# Diseases related to 'Athetosis': ['epilepsy syndrome', "Parkinson's disease", 'multiple sclerosis']
# Diseases related to 'Auditory Perceptual Disorders': ['bipolar disorder', 'attention deficit hyperactivity disorder', 'autistic disorder', 'alcohol dependence', 'schizophrenia']
# Diseases related to 'Back Pain': ['sarcoma', 'degenerative disc disease', 'lung cancer', "Paget's disease of bone", 'meningioma', 'retroperitoneal cancer', 'psoriasis', 'malignant glioma', 'ankylosing spondylitis', 'endogenous depression', 'kidney cancer', 'peripheral nervous system neoplasm', 'pancreatic cancer', 'osteoporosis', 'vascular cancer', 'mediastinal cancer', 'bone cancer', 'testicular cancer', 'rheumatoid arthritis', 'thoracic aortic aneurysm', 'germ cell cancer', 'abdominal aortic aneurysm', 'muscle cancer', 'nephrolithiasis', 'psoriatic arthritis', 'osteoarthritis', 'gout', 'spinal cancer']
# Diseases related to 'Birth Weight': ['cervical cancer', 'breast cancer', 'polycystic ovary syndrome', 'malaria', 'periodontitis', 'gestational diabetes', 'asthma', 'hypertension', 'hypothyroidism', 'cleft lip', 'dental caries', 'type 2 diabetes mellitus', 'type 1 diabetes mellitus', 'anemia']
# Diseases related to 'Urinary Bladder, Neurogenic': ["Behcet's disease", 'systemic lupus erythematosus', 'uterine cancer', 'type 1 diabetes mellitus', 'urinary bladder cancer', 'multiple sclerosis', 'muscle cancer', 'germ cell cancer', 'bone cancer', 'spinal cancer', 'chronic kidney failure', "Parkinson's disease", 'retroperitoneal cancer', 'cervical cancer', 'nephrolithiasis', 'rectum cancer']
# Diseases related to 'Blindness': ['refractive error', 'multiple sclerosis', 'peripheral nervous system neoplasm', 'age related macular degeneration', 'type 1 diabetes mellitus', 'leprosy', 'acquired immunodeficiency syndrome', 'melanoma', 'head and neck cancer', 'glaucoma', "Graves' disease", 'malignant glioma', 'pharynx cancer', 'intracranial aneurysm', 'brain cancer', 'ocular cancer', 'germ cell cancer', "Behcet's disease", 'meningioma', 'bone cancer']
# Diseases related to 'Body Temperature Changes': []
# Diseases related to 'Body Weight': ['metabolic syndrome X', 'sarcoma', 'liver cancer', 'urinary bladder cancer', 'osteoporosis', 'nicotine dependence', "Crohn's disease", 'celiac disease', 'chronic kidney failure', 'hypothyroidism', 'type 1 diabetes mellitus', 'esophageal cancer', 'dental caries', 'breast cancer', 'hypertension', 'atherosclerosis', 'stomach cancer', 'alcohol dependence', 'type 2 diabetes mellitus', 'colon cancer', 'polycystic ovary syndrome', 'obesity', 'dilated cardiomyopathy']
# Diseases related to 'Body Weight Changes': []
# Diseases related to 'Brain Death': ['chronic kidney failure', 'germ cell cancer', 'brain cancer', 'intracranial aneurysm', 'malignant glioma', 'type 1 diabetes mellitus', 'liver cancer', 'dilated cardiomyopathy', 'hepatitis B']
# Diseases related to 'Bulimia': ['polycystic ovary syndrome', 'panic disorder', 'type 1 diabetes mellitus', 'attention deficit hyperactivity disorder', 'obesity', 'alcohol dependence', 'endogenous depression', 'bipolar disorder', 'dental caries']
# Diseases related to 'Cachexia': ['chronic obstructive pulmonary disease', 'lung cancer', 'melanoma', 'germ cell cancer', 'acquired immunodeficiency syndrome', 'testicular cancer', 'malignant glioma', 'brain cancer', 'stomach cancer', 'breast cancer', 'head and neck cancer', 'peritoneum cancer', 'colon cancer', 'kidney cancer', 'chronic kidney failure', 'pancreatic cancer', 'liver cancer', 'rheumatoid arthritis', 'sarcoma', 'esophageal cancer', 'ovarian cancer']
# Diseases related to 'Cardiac Output, Low': ['abdominal aortic aneurysm', 'thoracic aortic aneurysm', 'anemia', 'adrenal gland cancer', 'dilated cardiomyopathy', 'coronary artery disease', 'hypertension']
# Diseases related to 'Catalepsy': ['schizophrenia', 'narcolepsy', "Parkinson's disease", 'Gilles de la Tourette syndrome', 'epilepsy syndrome']
# Diseases related to 'Cataplexy': ['narcolepsy']
# Diseases related to 'Catatonia': ['endogenous depression', 'autistic disorder', 'bipolar disorder', 'systemic lupus erythematosus', 'schizophrenia']
# Diseases related to 'Causalgia': ['alopecia areata']
# Diseases related to 'Cerebellar Ataxia': ['malaria', 'celiac disease', 'malignant glioma', 'hypothyroidism', 'migraine', 'brain cancer', 'multiple sclerosis', 'mediastinal cancer', 'Creutzfeldt-Jakob disease', 'epilepsy syndrome', 'amyotrophic lateral sclerosis', 'germ cell cancer', 'fallopian tube cancer', 'alcohol dependence', 'lung cancer', "Parkinson's disease", 'bipolar disorder']
# Diseases related to 'Cerebrospinal Fluid Otorrhea': ['meningioma', 'peripheral nervous system neoplasm', 'brain cancer', 'germ cell cancer', 'head and neck cancer', 'pharynx cancer', 'bone cancer', 'otosclerosis']
# Diseases related to 'Cerebrospinal Fluid Rhinorrhea': ['bone cancer', 'allergic rhinitis', 'malignant glioma', 'peripheral nervous system neoplasm', 'pharynx cancer', 'brain cancer', 'intracranial aneurysm', 'germ cell cancer', 'meningioma', 'head and neck cancer']
# Diseases related to 'Chest Pain': ['germ cell cancer', 'vascular cancer', 'esophageal cancer', 'anemia', 'sarcoma', 'malignant mesothelioma', "Barrett's esophagus", 'adrenal gland cancer', 'asthma', 'systemic lupus erythematosus', 'dilated cardiomyopathy', 'tracheal cancer', 'mediastinal cancer', 'coronary artery disease', 'uterine fibroid', 'abdominal aortic aneurysm', 'thymus cancer', 'head and neck cancer', 'panic disorder', 'thoracic aortic aneurysm', 'lung cancer']
# Diseases related to 'Cheyne-Stokes Respiration': ['dilated cardiomyopathy']
# Diseases related to 'Chorea': ['brain cancer', "Parkinson's disease", "Graves' disease", 'Gilles de la Tourette syndrome', 'bipolar disorder', 'rheumatoid arthritis', 'epilepsy syndrome', 'acquired immunodeficiency syndrome', 'systemic lupus erythematosus', 'hypothyroidism', 'multiple sclerosis']
# Diseases related to 'Choroid Hemorrhage': ['ocular cancer', 'refractive error', 'age related macular degeneration', 'glaucoma', 'germ cell cancer', 'melanoma']
# Diseases related to 'Colic': ['bile duct cancer', 'peritoneum cancer', 'gallbladder cancer', 'uterine fibroid', 'duodenum cancer', 'pancreatitis', 'melanoma', 'jejunal cancer', 'ulcerative colitis', 'colon cancer', 'ureter cancer', 'abdominal aortic aneurysm', 'kidney cancer', 'germ cell cancer', 'nephrolithiasis', 'migraine', 'retroperitoneal cancer', "Crohn's disease"]
# Diseases related to 'Color Vision Defects': ['type 1 diabetes mellitus', 'ocular cancer', 'age related macular degeneration', 'multiple sclerosis', 'refractive error', 'glaucoma', 'alcohol dependence', 'anemia', 'bipolar disorder']
# Diseases related to 'Coma': ["Paget's disease of bone", 'intracranial aneurysm', 'malignant mesothelioma', 'epilepsy syndrome', 'alcohol dependence', 'meningioma', 'malaria', 'bipolar disorder', 'brain cancer', 'hypothyroidism']
# Diseases related to 'Communication Disorders': ["Alzheimer's disease", "Parkinson's disease", 'amyotrophic lateral sclerosis', 'attention deficit hyperactivity disorder', 'conduct disorder', 'cleft lip', 'schizophrenia', 'autistic disorder']
# Diseases related to 'Confusion': ['intracranial aneurysm', 'meningioma', 'migraine', 'brain cancer', 'schizophrenia', 'Creutzfeldt-Jakob disease', "Parkinson's disease", 'endogenous depression', 'lung cancer', 'alcohol dependence', 'systemic lupus erythematosus', 'pancreatic cancer', 'malignant glioma', 'epilepsy syndrome', "Alzheimer's disease", 'bipolar disorder']
# Diseases related to 'Consciousness Disorders': ['malaria', 'alcohol dependence', 'intracranial aneurysm', 'migraine', 'meningioma', 'brain cancer', 'epilepsy syndrome']
# Diseases related to 'Constipation': ['lung cancer', 'uterine fibroid', "Crohn's disease", 'prostate cancer', 'uterine cancer', 'hypothyroidism', 'endogenous depression', 'ulcerative colitis', 'germ cell cancer', 'systemic scleroderma', 'retroperitoneal cancer', 'celiac disease', 'colon cancer', 'autistic disorder', 'stomach cancer', "Parkinson's disease", 'rectum cancer', 'cervical cancer', 'ovarian cancer', 'multiple sclerosis', 'peritoneum cancer']
# Diseases related to 'Cough': ['esophageal cancer', 'allergic rhinitis', 'tracheal cancer', 'chronic obstructive pulmonary disease', 'larynx cancer', 'malignant mesothelioma', 'lung cancer', 'vascular cancer', 'asthma', 'mediastinal cancer', 'head and neck cancer', 'acquired immunodeficiency syndrome', 'amyotrophic lateral sclerosis', 'idiopathic pulmonary fibrosis', 'thymus cancer', 'sarcoma']
# Diseases related to 'Cri-du-Chat Syndrome': ['anemia', 'autistic disorder']
# Diseases related to 'Cyanosis': ['cleft lip', 'lung cancer', 'mediastinal cancer', 'anemia', 'systemic scleroderma', 'asthma', 'chronic obstructive pulmonary disease', 'germ cell cancer']
# Diseases related to 'De Lange Syndrome': ['ulcerative colitis', 'autistic disorder', "Barrett's esophagus", 'refractive error']
# Diseases related to 'Deafness': ['refractive error', 'germ cell cancer', 'type 1 diabetes mellitus', 'brain cancer', 'skin cancer', 'otosclerosis', 'ocular cancer', 'meningioma', 'head and neck cancer', 'cleft lip', 'autistic disorder', 'vitiligo', 'pharynx cancer', "Paget's disease of bone", 'hypothyroidism', 'peripheral nervous system neoplasm']
# Diseases related to 'Hearing Loss, Sudden': ['pharynx cancer', 'germ cell cancer', 'brain cancer', 'head and neck cancer', 'multiple sclerosis', "Behcet's disease", 'peripheral nervous system neoplasm', 'meningioma']
# Diseases related to 'Decerebrate State': ['epilepsy syndrome', 'hypertension', 'intracranial aneurysm']
# Diseases related to 'Delirium': ["Parkinson's disease", 'bipolar disorder', 'alcohol dependence', "Alzheimer's disease", 'schizophrenia', 'acquired immunodeficiency syndrome', 'endogenous depression']
# Diseases related to 'Diarrhea': ["Crohn's disease", 'rectum cancer', 'melanoma', 'ileum cancer', 'anemia', 'ulcerative colitis', "Behcet's disease", 'jejunal cancer', 'lung cancer', 'hematologic cancer', 'kidney cancer', 'adrenal gland cancer', 'duodenum cancer', 'malaria', 'acquired immunodeficiency syndrome', 'prostate cancer', 'psoriasis', 'pancreatitis', 'colon cancer', 'urinary bladder cancer', 'uterine cancer', 'systemic scleroderma', 'germ cell cancer', 'liver cancer', 'breast cancer', 'stomach cancer', 'peritoneum cancer', 'head and neck cancer', 'thyroid cancer', 'esophageal cancer', 'thymus cancer', 'pancreatic cancer', 'cervical cancer', 'celiac disease']
# Diseases related to 'Diarrhea, Infantile': ['germ cell cancer', 'retroperitoneal cancer', 'ulcerative colitis', 'celiac disease', 'adrenal gland cancer', 'malaria', 'anemia']
# Diseases related to 'Diplopia': ['melanoma', 'intracranial aneurysm', 'age related macular degeneration', 'pharynx cancer', 'sarcoma', 'germ cell cancer', 'ocular cancer', "Graves' disease", 'refractive error', 'multiple sclerosis', 'systemic lupus erythematosus', 'bone cancer', 'peripheral nervous system neoplasm', 'brain cancer', 'malignant glioma', 'muscle cancer', 'head and neck cancer', 'meningioma']
# Diseases related to 'Dizziness': ['otosclerosis', 'multiple sclerosis', 'panic disorder', 'migraine', 'endogenous depression', 'malignant glioma', 'meningioma', 'brain cancer', 'ankylosing spondylitis', 'germ cell cancer', "Paget's disease of bone", 'peripheral nervous system neoplasm', 'intracranial aneurysm', 'hypertension', 'head and neck cancer']
# Diseases related to 'Down Syndrome': ['cleft lip', "Alzheimer's disease", 'periodontitis', 'alopecia areata', 'vitiligo', 'celiac disease', "Graves' disease", 'hepatitis B', 'hypothyroidism', 'psoriasis', 'dental caries', 'autistic disorder', 'skin cancer', 'ocular cancer', 'sclerosing cholangitis', 'type 1 diabetes mellitus', 'testicular cancer', 'germ cell cancer', 'refractive error']
# Diseases related to 'Dysarthria': ['multiple sclerosis', 'malignant glioma', 'Creutzfeldt-Jakob disease', 'amyotrophic lateral sclerosis', 'intracranial aneurysm', "Behcet's disease", 'germ cell cancer', "Parkinson's disease", 'brain cancer']
# Diseases related to 'Dysgeusia': ['lung cancer', 'thymus cancer', 'head and neck cancer']
# Diseases related to 'Dyskinesia, Drug-Induced': ['endogenous depression', 'bipolar disorder', 'schizophrenia', 'Gilles de la Tourette syndrome', "Parkinson's disease"]
# Diseases related to 'Dyslexia': ['conduct disorder', 'refractive error', 'cleft lip', 'attention deficit hyperactivity disorder', 'schizophrenia', 'autistic disorder']
# Diseases related to 'Dyslexia, Acquired': ['germ cell cancer', 'meningioma', 'multiple sclerosis', 'malignant glioma', 'brain cancer', 'intracranial aneurysm', "Alzheimer's disease"]
# Diseases related to 'Dysmenorrhea': ['ovarian cancer', 'migraine', 'fallopian tube cancer', 'uterine fibroid', 'uterine cancer', 'polycystic ovary syndrome', 'cervical cancer']
# Diseases related to 'Dyspepsia': ['chronic kidney failure', 'rheumatoid arthritis', 'systemic scleroderma', 'anemia', 'pancreatic cancer', 'duodenum cancer', "Crohn's disease", 'osteoarthritis', 'endogenous depression', 'head and neck cancer', 'uterine fibroid', 'pancreatitis', 'esophageal cancer', 'type 1 diabetes mellitus', 'celiac disease', 'stomach cancer', 'ulcerative colitis', "Barrett's esophagus"]
# Diseases related to 'Dyspnea': ['larynx cancer', 'sarcoma', 'systemic scleroderma', 'mediastinal cancer', 'esophageal cancer', 'thyroid cancer', 'muscle cancer', 'dilated cardiomyopathy', 'panic disorder', 'amyotrophic lateral sclerosis', 'thoracic aortic aneurysm', 'pharynx cancer', 'vascular cancer', 'asthma', 'lung cancer', 'chronic obstructive pulmonary disease', 'head and neck cancer', 'tracheal cancer', 'malignant mesothelioma', 'idiopathic pulmonary fibrosis', 'thymus cancer']
# Diseases related to 'Dyspnea, Paroxysmal': ['chronic obstructive pulmonary disease', 'asthma']
# Diseases related to 'Dystonia': ['epilepsy syndrome', 'vitiligo', 'bipolar disorder', "Parkinson's disease", 'endogenous depression', 'Creutzfeldt-Jakob disease', 'schizophrenia', 'Gilles de la Tourette syndrome', 'multiple sclerosis']
# Diseases related to 'Earache': ['germ cell cancer', 'salivary gland cancer', 'bone cancer', 'head and neck cancer', 'lung cancer', 'pharynx cancer', 'larynx cancer']
# Diseases related to 'Ecchymosis': ['liver cancer', 'adrenal gland cancer', 'germ cell cancer', 'bone cancer', 'thoracic aortic aneurysm', 'head and neck cancer', 'sarcoma', 'skin cancer', 'kidney cancer', 'systemic lupus erythematosus', 'ocular cancer', 'pancreatitis']
# Diseases related to 'Echolalia': ['Gilles de la Tourette syndrome', 'Creutzfeldt-Jakob disease', 'autistic disorder']
# Diseases related to 'Edema': ['ovarian cancer', 'pancreatitis', 'melanoma', 'sarcoma', 'rheumatoid arthritis', 'Kawasaki disease', "Crohn's disease", 'breast cancer', 'retroperitoneal cancer', 'head and neck cancer', 'systemic lupus erythematosus', 'osteoporosis', 'prostate cancer', 'vulva cancer', 'bone cancer', 'ocular cancer', 'cervical cancer', 'systemic scleroderma', 'membranous glomerulonephritis', 'gout', 'uterine fibroid', 'psoriasis', 'fallopian tube cancer', 'hypertension', 'vascular cancer', 'penile cancer', 'ankylosing spondylitis', 'stomach cancer', 'chronic kidney failure', 'atopic dermatitis', "Fuchs' endothelial dystrophy", 'anemia', 'skin cancer', 'larynx cancer', 'muscle cancer', 'allergic rhinitis', 'germ cell cancer', 'leprosy', 'mediastinal cancer', 'glaucoma', 'age related macular degeneration', 'pharynx cancer', 'osteoarthritis', 'psoriatic arthritis', 'periodontitis', 'urinary bladder cancer', "Graves' disease", 'hypothyroidism', 'uterine cancer']
# Diseases related to 'Edema, Cardiac': ['coronary artery disease', 'dilated cardiomyopathy', 'chronic kidney failure', 'systemic scleroderma']
# Diseases related to 'Emaciation': ['brain cancer', 'malignant glioma', 'peripheral nervous system neoplasm', 'acquired immunodeficiency syndrome', 'anemia', 'stomach cancer', 'germ cell cancer', 'osteoporosis']
# Diseases related to 'Encopresis': ['attention deficit hyperactivity disorder', 'autistic disorder']
# Diseases related to 'Eructation': ['stomach cancer', "Crohn's disease"]
# Diseases related to 'Eye Hemorrhage': ['age related macular degeneration', 'muscle cancer', 'refractive error', 'glaucoma', 'ocular cancer', 'germ cell cancer', 'malaria', 'melanoma']
# Diseases related to 'Eye Manifestations': ['multiple sclerosis', 'systemic scleroderma', 'pharynx cancer', 'intracranial aneurysm', 'systemic lupus erythematosus', 'ulcerative colitis', 'hypertension', 'adrenal gland cancer', 'germ cell cancer', "Behcet's disease", 'meningioma', 'brain cancer', 'malignant glioma', 'head and neck cancer', 'rheumatoid arthritis', 'glaucoma', 'leprosy', "Graves' disease", 'skin cancer', 'ocular cancer', 'bone cancer', 'ankylosing spondylitis', 'anemia']
# Diseases related to 'Facial Pain': ['germ cell cancer', 'bone cancer', 'lung cancer', 'salivary gland cancer', 'psoriasis', 'brain cancer', 'osteoarthritis', 'migraine', 'rheumatoid arthritis', 'intracranial aneurysm', 'head and neck cancer', 'meningioma', 'peripheral nervous system neoplasm', 'dental caries', 'periodontitis', 'pharynx cancer', 'ocular cancer']
# Diseases related to 'Facial Paralysis': ['salivary gland cancer', 'leprosy', 'intracranial aneurysm', 'pharynx cancer', 'malignant glioma', 'meningioma', 'brain cancer', "Behcet's disease", 'germ cell cancer', 'skin cancer', 'muscle cancer', 'otosclerosis', 'peripheral nervous system neoplasm', 'multiple sclerosis', 'Kawasaki disease', 'bone cancer', 'head and neck cancer', 'sarcoma', 'acquired immunodeficiency syndrome']
# Diseases related to 'Failure to Thrive': ['endogenous depression', 'cleft lip', 'anemia', 'germ cell cancer', 'dental caries', 'hypothyroidism', 'acquired immunodeficiency syndrome', "Crohn's disease", 'celiac disease', 'malignant glioma', 'ulcerative colitis', 'dilated cardiomyopathy', 'brain cancer']
# Diseases related to 'Fasciculation': ['multiple sclerosis', 'amyotrophic lateral sclerosis', 'malignant glioma', 'thymus cancer']
# Diseases related to 'Fatigue': ['melanoma', 'hypothyroidism', 'multiple sclerosis', 'systemic scleroderma', 'chronic obstructive pulmonary disease', 'anemia', 'rectum cancer', 'rheumatoid arthritis', "Parkinson's disease", 'psoriasis', 'systemic lupus erythematosus', 'primary biliary cirrhosis', 'sclerosing cholangitis', 'prostate cancer', 'lung cancer', 'kidney cancer', 'hematologic cancer', 'psoriatic arthritis', 'chronic kidney failure', 'breast cancer', 'stomach cancer', 'ankylosing spondylitis', 'esophageal cancer', 'ovarian cancer', 'endogenous depression']
# Diseases related to 'Mental Fatigue': ['primary biliary cirrhosis', 'endogenous depression', 'breast cancer', 'multiple sclerosis']
# Diseases related to 'Feminization': ['testicular cancer', 'alcohol dependence', 'prostate cancer', 'ovarian cancer', 'liver cancer', 'adrenal gland cancer']
# Diseases related to 'Fetal Hypoxia': ['asthma', 'anemia', 'hypertension', 'malaria', 'gestational diabetes', 'epilepsy syndrome', 'schizophrenia', 'dilated cardiomyopathy', 'nicotine dependence']
# Diseases related to 'Fetal Distress': ['hypertension', 'type 1 diabetes mellitus', 'anemia', 'gestational diabetes']
# Diseases related to 'Fetal Macrosomia': ['gestational diabetes', 'type 1 diabetes mellitus']
# Diseases related to 'Fever': ['rectum cancer', 'leprosy', 'rheumatoid arthritis', 'adrenal gland cancer', 'breast cancer', 'uterine fibroid', 'abdominal aortic aneurysm', 'psoriasis', "Crohn's disease", 'kidney cancer', 'malignant mesothelioma', 'stomach cancer', 'sarcoma', 'colon cancer', 'melanoma', 'malaria', 'Kawasaki disease', 'nephrolithiasis', 'mediastinal cancer', 'hepatitis B', 'skin cancer', 'ulcerative colitis', 'gout', 'acquired immunodeficiency syndrome', 'hematologic cancer', 'urinary bladder cancer', 'germ cell cancer', 'uterine cancer', 'epilepsy syndrome', 'peritoneum cancer', 'ovarian cancer', 'retroperitoneal cancer', 'systemic lupus erythematosus', 'lung cancer', "Behcet's disease", 'cervical cancer', 'anemia', 'vascular cancer', 'liver cancer']
# Diseases related to 'Fever of Unknown Origin': ["Crohn's disease", 'hematologic cancer', 'liver cancer', 'kidney cancer', 'thoracic aortic aneurysm', 'colon cancer', 'cervical cancer', 'vascular cancer', 'gallbladder cancer', 'systemic lupus erythematosus', 'uterine fibroid', 'ulcerative colitis', 'sarcoma', 'acquired immunodeficiency syndrome', 'malignant mesothelioma', 'adrenal gland cancer', "Behcet's disease", 'malaria', 'uterine cancer', 'retroperitoneal cancer', 'rheumatoid arthritis', 'anemia', 'Kawasaki disease', 'peritoneum cancer', 'abdominal aortic aneurysm']
# Diseases related to 'Flatulence': ['colon cancer', 'rectum cancer', 'celiac disease', 'ulcerative colitis', 'urinary bladder cancer', 'prostate cancer', 'stomach cancer', 'ovarian cancer']
# Diseases related to 'Flushing': ['esophageal cancer', 'type 2 diabetes mellitus', 'liver cancer', 'schizophrenia', 'adrenal gland cancer', 'prostate cancer', 'ileum cancer', 'germ cell cancer', 'mediastinal cancer', 'alcohol dependence', 'head and neck cancer', 'psoriasis']
# Diseases related to 'Fragile X Syndrome': ['attention deficit hyperactivity disorder', 'autistic disorder']
# Diseases related to 'Gagging': []
# Diseases related to 'Gerstmann Syndrome': ['germ cell cancer', 'malignant glioma', 'brain cancer']
# Diseases related to 'Gingival Hemorrhage': ['type 1 diabetes mellitus', 'dental caries', 'cleft lip', 'periodontitis']
# Diseases related to 'Glossalgia': ['endogenous depression', 'head and neck cancer', 'anemia']
# Diseases related to 'Halitosis': ['head and neck cancer', 'dental caries', 'periodontitis', 'cleft lip']
# Diseases related to 'Hallucinations': ['migraine', 'Creutzfeldt-Jakob disease', 'panic disorder', "Parkinson's disease", 'age related macular degeneration', 'narcolepsy', "Alzheimer's disease", 'bipolar disorder', 'alcohol dependence', 'schizophrenia', 'endogenous depression']
# Diseases related to 'Headache': ['peripheral nervous system neoplasm', 'adrenal gland cancer', 'brain cancer', 'head and neck cancer', 'allergic rhinitis', 'germ cell cancer', "Behcet's disease", 'migraine', 'bone cancer', 'hypertension', 'malignant glioma', 'systemic lupus erythematosus', 'endogenous depression', 'meningioma', 'intracranial aneurysm']
# Diseases related to 'Hearing Disorders': ['vitiligo', 'alopecia areata', 'hypothyroidism', 'cleft lip', 'chronic kidney failure', 'autistic disorder', 'meningioma', 'multiple sclerosis', 'malignant glioma', 'otosclerosis', 'head and neck cancer', "Paget's disease of bone", 'testicular cancer', 'peripheral nervous system neoplasm', 'brain cancer', "Behcet's disease", 'germ cell cancer', 'pharynx cancer']
# Diseases related to 'Hearing Loss, Bilateral': ['otosclerosis', "Paget's disease of bone", 'meningioma', 'head and neck cancer', "Behcet's disease", 'brain cancer', 'germ cell cancer', 'peripheral nervous system neoplasm']
# Diseases related to 'Hearing Loss, Central': ['peripheral nervous system neoplasm', 'germ cell cancer', 'brain cancer', 'malignant glioma', 'multiple sclerosis', 'meningioma']
# Diseases related to 'Hearing Loss, Conductive': ['pharynx cancer', 'otosclerosis', 'bone cancer', 'head and neck cancer', 'salivary gland cancer', 'peripheral nervous system neoplasm', 'cleft lip', "Paget's disease of bone", 'rheumatoid arthritis', 'germ cell cancer']
# Diseases related to 'Hearing Loss, Functional': ['germ cell cancer', 'peripheral nervous system neoplasm', 'pharynx cancer', 'attention deficit hyperactivity disorder']
# Diseases related to 'Hearing Loss, High-Frequency': ['chronic kidney failure', 'type 1 diabetes mellitus', 'vitiligo', 'otosclerosis', 'peripheral nervous system neoplasm', 'head and neck cancer', 'testicular cancer', 'multiple sclerosis', 'germ cell cancer', 'brain cancer']
# Diseases related to 'Hearing Loss, Noise-Induced': ['peripheral nervous system neoplasm', 'otosclerosis', 'hypertension']
# Diseases related to 'Hearing Loss, Sensorineural': ['dilated cardiomyopathy', 'pharynx cancer', 'peripheral nervous system neoplasm', 'ulcerative colitis', 'ankylosing spondylitis', 'head and neck cancer', "Paget's disease of bone", 'germ cell cancer', 'salivary gland cancer', 'malignant glioma', 'Kawasaki disease', 'brain cancer', 'meningioma', "Behcet's disease", 'vitiligo', 'multiple sclerosis', 'systemic scleroderma', 'anemia', 'rheumatoid arthritis', 'otosclerosis', 'systemic lupus erythematosus', 'type 1 diabetes mellitus', 'hypothyroidism', 'bone cancer']
# Diseases related to 'Heart Murmurs': ['Kawasaki disease', 'thoracic aortic aneurysm', 'dilated cardiomyopathy', 'sarcoma', 'anemia', 'germ cell cancer', 'chronic kidney failure', 'thymus cancer', 'hypertension', 'mediastinal cancer', 'coronary artery disease']
# Diseases related to 'Heartburn': ['stomach cancer', 'head and neck cancer', 'rheumatoid arthritis', 'idiopathic pulmonary fibrosis', 'esophageal cancer', 'systemic scleroderma', "Barrett's esophagus"]
# Diseases related to 'Hematemesis': ['jejunal cancer', 'testicular cancer', 'uterine fibroid', 'mediastinal cancer', 'sarcoma', 'abdominal aortic aneurysm', 'germ cell cancer', 'anemia', 'duodenum cancer', 'pancreatic cancer', 'liver cancer', 'pancreatitis', 'thoracic aortic aneurysm', 'head and neck cancer', 'esophageal cancer', 'stomach cancer']
# Diseases related to 'Hemianopsia': ['multiple sclerosis', 'glaucoma', 'intracranial aneurysm', 'meningioma', 'testicular cancer', 'peripheral nervous system neoplasm', 'migraine', 'Creutzfeldt-Jakob disease', 'malignant glioma', 'brain cancer', 'germ cell cancer']
# Diseases related to 'Hemiplegia': ['brain cancer', 'meningioma', 'germ cell cancer', 'migraine', 'systemic lupus erythematosus', 'rheumatoid arthritis', 'malignant glioma', "Behcet's disease", 'epilepsy syndrome', 'osteoporosis', 'intracranial aneurysm', 'multiple sclerosis']
# Diseases related to 'Hemoglobinuria': ['anemia', 'malaria']
# Diseases related to 'Hemoptysis': ['mediastinal cancer', 'thymus cancer', "Behcet's disease", 'larynx cancer', 'vascular cancer', 'esophageal cancer', 'sarcoma', 'thyroid cancer', 'malignant mesothelioma', 'lung cancer', 'systemic lupus erythematosus', 'tracheal cancer', 'germ cell cancer', 'head and neck cancer', 'thoracic aortic aneurysm', 'chronic obstructive pulmonary disease']
# Diseases related to 'Oral Hemorrhage': ['cleft lip', 'bone cancer', 'head and neck cancer', 'periodontitis', 'pharynx cancer', 'anemia', 'dental caries']
# Diseases related to 'Hiccup': ['stomach cancer', 'brain cancer', 'malignant glioma', 'esophageal cancer', 'multiple sclerosis', "Parkinson's disease", 'intracranial aneurysm']
# Diseases related to 'Hirsutism': ['ovarian cancer', 'testicular cancer', 'adrenal gland cancer', 'polycystic ovary syndrome']
# Diseases related to 'Hoarseness': ['asthma', 'head and neck cancer', 'mediastinal cancer', 'esophageal cancer', 'muscle cancer', 'pharynx cancer', 'sarcoma', 'peripheral nervous system neoplasm', 'rheumatoid arthritis', 'tracheal cancer', 'lung cancer', 'thyroid cancer', 'hypothyroidism', 'larynx cancer', 'germ cell cancer', 'thoracic aortic aneurysm']
# Diseases related to 'Horner Syndrome': ['mediastinal cancer', 'migraine', 'ocular cancer', 'intracranial aneurysm', 'bone cancer', 'thyroid cancer', 'germ cell cancer', 'spinal cancer', 'peripheral nervous system neoplasm', 'lung cancer', 'pharynx cancer', 'brain cancer', 'head and neck cancer']
# Diseases related to 'Huntington Disease': ['multiple sclerosis', "Alzheimer's disease", "Parkinson's disease", 'Creutzfeldt-Jakob disease', 'schizophrenia', 'endogenous depression', 'Gilles de la Tourette syndrome', 'amyotrophic lateral sclerosis']
# Diseases related to 'Hyperalgesia': ['nicotine dependence', 'sarcoma', 'skin cancer', 'rheumatoid arthritis', 'pancreatitis', 'migraine', 'gout', 'bone cancer', 'osteoarthritis', 'melanoma']
# Diseases related to 'Hypercapnia': ['chronic obstructive pulmonary disease', 'asthma', 'panic disorder', 'amyotrophic lateral sclerosis']
# Diseases related to 'Hyperemesis Gravidarum': ['uterine cancer', 'stomach cancer', 'germ cell cancer']
# Diseases related to 'Hyperesthesia': ['alcohol dependence', 'migraine', 'leprosy']
# Diseases related to 'Hypergammaglobulinemia': ["Graves' disease", 'sclerosing cholangitis', 'skin cancer', 'malaria', 'systemic lupus erythematosus', 'thymus cancer', 'psoriasis', 'pancreatitis', 'rheumatoid arthritis', 'acquired immunodeficiency syndrome', 'hepatitis B', 'atopic dermatitis', 'systemic scleroderma', 'ankylosing spondylitis', 'anemia', 'IgA glomerulonephritis', 'liver cancer', 'primary biliary cirrhosis']
# Diseases related to 'Hyperkinesis': ['autistic disorder', "Parkinson's disease", 'Gilles de la Tourette syndrome', 'attention deficit hyperactivity disorder', 'bipolar disorder', 'conduct disorder', 'epilepsy syndrome', 'schizophrenia']
# Diseases related to 'Hyperphagia': ['endogenous depression', 'obesity', 'alcohol dependence']
# Diseases related to 'Disorders of Excessive Somnolence': ['attention deficit hyperactivity disorder', "Parkinson's disease", 'narcolepsy', 'restless legs syndrome', 'bipolar disorder', 'multiple sclerosis', 'endogenous depression', 'allergic rhinitis']
# Diseases related to 'Hyperventilation': ['asthma', 'chronic obstructive pulmonary disease', 'epilepsy syndrome', 'migraine', 'malignant glioma', 'panic disorder', 'brain cancer']
# Diseases related to 'Hypesthesia': ['meningioma', 'sarcoma', 'systemic scleroderma', 'salivary gland cancer', 'malignant glioma', "Graves' disease", 'head and neck cancer', 'breast cancer', "Fuchs' endothelial dystrophy", 'bone cancer', 'ankylosing spondylitis', 'spinal cancer', 'germ cell cancer', 'peripheral nervous system neoplasm', 'multiple sclerosis', 'brain cancer', 'leprosy']
# Diseases related to 'Hyphema': ['melanoma', 'germ cell cancer', 'glaucoma', 'anemia', 'ocular cancer']
# Diseases related to 'Hypotension, Orthostatic': ['endogenous depression', 'type 1 diabetes mellitus', "Parkinson's disease", 'hypertension', 'adrenal gland cancer']
# Diseases related to 'Hypothermia': ['pancreatitis', 'hypothyroidism', 'abdominal aortic aneurysm', 'multiple sclerosis', 'alcohol dependence']
# Diseases related to 'Hypoventilation': ['lung cancer', 'chronic obstructive pulmonary disease', 'germ cell cancer', 'asthma', 'obesity', 'amyotrophic lateral sclerosis', 'hypothyroidism']
# Diseases related to 'Illusions': ['attention deficit hyperactivity disorder', 'migraine', 'schizophrenia', 'epilepsy syndrome', "Parkinson's disease"]
# Diseases related to 'Sleep Initiation and Maintenance Disorders': ['restless legs syndrome', 'alcohol dependence', "Parkinson's disease", 'breast cancer', 'schizophrenia', "Alzheimer's disease", 'bipolar disorder', 'panic disorder', 'narcolepsy', 'Creutzfeldt-Jakob disease', 'attention deficit hyperactivity disorder', 'nicotine dependence', 'endogenous depression']
# Diseases related to 'Insulin Coma': ['pancreatic cancer', 'schizophrenia', 'type 1 diabetes mellitus']
# Diseases related to 'Intermittent Claudication': ['abdominal aortic aneurysm', 'vascular cancer', 'coronary artery disease', 'hypertension', 'atherosclerosis']
# Diseases related to 'Jaundice': ['sclerosing cholangitis', 'anemia', 'ulcerative colitis', 'pancreatitis', 'malaria', 'liver cancer', 'Kawasaki disease', 'alcohol dependence', 'vitiligo', 'primary biliary cirrhosis', 'gallbladder cancer', 'pancreatic cancer', 'bile duct cancer', 'duodenum cancer', 'hepatitis B']
# Diseases related to 'Kearns-Sayre Syndrome': ['dilated cardiomyopathy', 'focal segmental glomerulosclerosis', 'epilepsy syndrome', 'type 1 diabetes mellitus', 'anemia']
# Diseases related to 'Menkes Kinky Hair Syndrome': ["Alzheimer's disease", 'osteoporosis', 'epilepsy syndrome']
# Diseases related to 'Language Development Disorders': ['autistic disorder', 'attention deficit hyperactivity disorder', 'conduct disorder', 'cleft lip']
# Diseases related to 'Language Disorders': ['schizophrenia', 'Gilles de la Tourette syndrome', 'attention deficit hyperactivity disorder', 'epilepsy syndrome', 'cleft lip', 'brain cancer', 'amyotrophic lateral sclerosis', 'autistic disorder', "Alzheimer's disease", 'malignant glioma', "Parkinson's disease"]
# Diseases related to 'Learning Disorders': ['attention deficit hyperactivity disorder', 'cleft lip', 'alcohol dependence', 'schizophrenia', 'autistic disorder', "Alzheimer's disease", 'epilepsy syndrome', 'endogenous depression', 'Gilles de la Tourette syndrome', 'bipolar disorder', 'conduct disorder']
# Diseases related to 'Lesch-Nyhan Syndrome': ['Gilles de la Tourette syndrome', 'gout', 'nephrolithiasis', 'bipolar disorder', 'chronic kidney failure', 'autistic disorder']
# Diseases related to 'Lipoid Proteinosis of Urbach and Wiethe': ['panic disorder']
# Diseases related to 'Memory Disorders': ["Alzheimer's disease", 'epilepsy syndrome', "Parkinson's disease", 'intracranial aneurysm', 'brain cancer', 'schizophrenia', 'attention deficit hyperactivity disorder', 'Creutzfeldt-Jakob disease', 'alcohol dependence', 'multiple sclerosis', 'malignant glioma', 'endogenous depression', 'bipolar disorder']
# Diseases related to 'Meningism': ['intracranial aneurysm', 'brain cancer', 'germ cell cancer']
# Diseases related to 'Intellectual Disability': ['kidney cancer', 'hepatitis B', 'anemia', 'endogenous depression', 'conduct disorder', 'bipolar disorder', 'epilepsy syndrome', 'hypothyroidism', 'attention deficit hyperactivity disorder', 'vitiligo', 'Gilles de la Tourette syndrome', 'autistic disorder', 'dental caries', 'skin cancer', 'cleft lip', 'alcohol dependence', 'schizophrenia']
# Diseases related to 'Monoclonal Gammopathy of Undetermined Significance': ['rheumatoid arthritis', 'psoriasis', 'anemia', 'bone cancer', 'hematologic cancer', 'thymus cancer', 'osteoporosis', 'membranous glomerulonephritis']
# Diseases related to 'Motion Sickness': ['panic disorder', 'migraine']
# Diseases related to 'Mouth Breathing': ['periodontitis', 'cleft lip', 'allergic rhinitis', 'asthma', 'dental caries']
# Diseases related to 'Muscle Cramp': ['chronic kidney failure', "Parkinson's disease", 'restless legs syndrome', 'multiple sclerosis', 'hypothyroidism', 'amyotrophic lateral sclerosis']
# Diseases related to 'Muscle Hypertonia': ['multiple sclerosis', "Parkinson's disease"]
# Diseases related to 'Muscle Hypotonia': ['thymus cancer', 'autistic disorder', 'spinal cancer', 'narcolepsy', 'refractive error', 'epilepsy syndrome', 'dilated cardiomyopathy']
# Diseases related to 'Muscle Rigidity': ["Parkinson's disease", "Alzheimer's disease"]
# Diseases related to 'Muscle Spasticity': ['amyotrophic lateral sclerosis', 'multiple sclerosis', 'Creutzfeldt-Jakob disease', 'spinal cancer']
# Diseases related to 'Muscular Atrophy': ['leprosy', 'rheumatoid arthritis', 'chronic kidney failure', 'spinal cancer', 'amyotrophic lateral sclerosis', 'hypothyroidism', 'peripheral nervous system neoplasm', 'lung cancer', 'osteoporosis', 'multiple sclerosis', 'chronic obstructive pulmonary disease', 'alcohol dependence', 'osteoarthritis', 'systemic scleroderma', 'ankylosing spondylitis', 'sarcoma']
# Diseases related to 'Mutism': ['autistic disorder', 'germ cell cancer', 'brain cancer', 'schizophrenia', 'malignant glioma']
# Diseases related to 'Myoclonus': ['mediastinal cancer', 'epilepsy syndrome', "Alzheimer's disease", 'restless legs syndrome', 'thymus cancer', 'Creutzfeldt-Jakob disease', 'brain cancer', 'Gilles de la Tourette syndrome', 'spinal cancer', 'germ cell cancer', 'adrenal gland cancer', 'malignant glioma']
# Diseases related to 'Myotonia': ['multiple sclerosis', 'hypothyroidism', 'amyotrophic lateral sclerosis']
# Diseases related to 'Narcolepsy': ['narcolepsy']
# Diseases related to 'Nausea': ['melanoma', "Parkinson's disease", 'malignant mesothelioma', 'lung cancer', 'hematologic cancer', 'breast cancer', 'kidney cancer', 'testicular cancer', 'ulcerative colitis', 'liver cancer', 'rheumatoid arthritis', 'rectum cancer', 'peritoneum cancer', 'urinary bladder cancer', 'colon cancer', 'skin cancer', 'stomach cancer', 'germ cell cancer', 'uterine cancer', 'malignant glioma', 'pancreatic cancer', 'esophageal cancer', 'acquired immunodeficiency syndrome', 'brain cancer', 'cervical cancer', "Crohn's disease", 'sarcoma', 'head and neck cancer', 'endogenous depression', 'psoriasis', 'migraine', 'ovarian cancer', 'prostate cancer', 'duodenum cancer']
# Diseases related to 'Neuralgia': ['peripheral nervous system neoplasm', 'pharynx cancer', 'bone cancer', 'acquired immunodeficiency syndrome', 'head and neck cancer', 'breast cancer', 'rheumatoid arthritis', 'osteoarthritis', 'ankylosing spondylitis', 'muscle cancer', 'migraine', 'spinal cancer', 'germ cell cancer', 'leprosy', 'multiple sclerosis', 'retroperitoneal cancer']
# Diseases related to 'Neurologic Manifestations': ['lung cancer', 'multiple sclerosis', 'sarcoma', 'intracranial aneurysm', 'retroperitoneal cancer', 'spinal cancer', "Graves' disease", 'pharynx cancer', 'germ cell cancer', 'pancreatic cancer', 'anemia', 'hypothyroidism', 'malaria', 'amyotrophic lateral sclerosis', "Behcet's disease", 'systemic scleroderma', "Paget's disease of bone", 'systemic lupus erythematosus', 'chronic kidney failure', 'head and neck cancer', 'ankylosing spondylitis', 'bone cancer', 'alcohol dependence', 'rheumatoid arthritis', 'malignant glioma', 'meningioma', 'leprosy', 'brain cancer']
# Diseases related to 'Night Blindness': ['melanoma', 'refractive error', 'germ cell cancer', 'ocular cancer', 'age related macular degeneration', 'primary biliary cirrhosis', 'skin cancer']
# Diseases related to 'Obesity': ['obesity', 'metabolic syndrome X', "Barrett's esophagus", 'type 2 diabetes mellitus', 'polycystic ovary syndrome']
# Diseases related to 'Obesity, Morbid': ['obesity']
# Diseases related to 'Oliguria': ['systemic scleroderma', 'hypertension', 'cervical cancer', 'kidney cancer', 'malaria', 'chronic kidney failure', 'anemia']
# Diseases related to 'Ophthalmoplegia': ['pharynx cancer', 'muscle cancer', 'migraine', 'refractive error', "Graves' disease", 'multiple sclerosis', 'bone cancer', 'ocular cancer', 'sarcoma', 'intracranial aneurysm', 'brain cancer', 'head and neck cancer', 'peripheral nervous system neoplasm', 'germ cell cancer', 'malignant glioma', 'amyotrophic lateral sclerosis', 'meningioma']
# Diseases related to 'Optical Illusions': ['migraine', 'schizophrenia', 'refractive error', 'autistic disorder']
# Diseases related to 'Oral Manifestations': ['head and neck cancer', "Paget's disease of bone", 'rheumatoid arthritis', "Behcet's disease", 'skin cancer', 'leprosy', 'systemic scleroderma', 'periodontitis', 'hypothyroidism', 'systemic lupus erythematosus', "Crohn's disease", 'psoriasis', 'bone cancer', 'dental caries', 'anemia']
# Diseases related to 'Pain': ['rheumatoid arthritis', 'sarcoma', 'gout', 'ankylosing spondylitis', 'degenerative disc disease', 'hematologic cancer', 'acquired immunodeficiency syndrome', 'vaginal cancer', 'penile cancer', 'systemic scleroderma', 'fallopian tube cancer', 'endogenous depression', 'uterine cancer', 'anemia', 'esophageal cancer', 'nephrolithiasis', 'ureter cancer', 'bone cancer', 'multiple sclerosis', 'muscle cancer', 'retroperitoneal cancer', 'kidney cancer', 'osteoporosis', 'osteoarthritis', 'head and neck cancer', 'psoriatic arthritis', 'spinal cancer', 'prostate cancer', 'migraine', 'breast cancer', 'psoriasis', 'uterine fibroid', 'lung cancer', 'vulva cancer', 'malignant mesothelioma', 'rectum cancer', "Paget's disease of bone", 'pancreatic cancer', 'cervical cancer', 'pancreatitis', 'skin cancer', "Crohn's disease"]
# Diseases related to 'Pain, Intractable': ['kidney cancer', 'lung cancer', 'cervical cancer', 'endogenous depression', 'colon cancer', 'head and neck cancer', 'migraine', 'prostate cancer', 'breast cancer', 'pancreatic cancer', 'spinal cancer', 'penile cancer', 'muscle cancer', 'sarcoma', 'bone cancer', 'uterine cancer', 'rectum cancer', 'pancreatitis']
# Diseases related to 'Pain, Postoperative': ['abdominal aortic aneurysm', 'osteoarthritis', 'adrenal gland cancer', "Crohn's disease", 'degenerative disc disease', 'esophageal cancer', 'rheumatoid arthritis', 'pancreatitis', 'stomach cancer', 'bone cancer', 'uterine cancer', 'rectum cancer', 'breast cancer', 'uterine fibroid', 'lung cancer', 'cervical cancer', 'periodontitis', 'cleft lip', 'urinary bladder cancer', 'thyroid cancer', 'nephrolithiasis', 'liver cancer', 'kidney cancer', 'skin cancer', 'prostate cancer', 'pancreatic cancer', 'refractive error', 'head and neck cancer', 'colon cancer']
# Diseases related to 'Pallor': ['glaucoma', 'anemia', 'malaria']
# Diseases related to 'Paralysis': ['malignant glioma', 'sarcoma', 'intracranial aneurysm', 'salivary gland cancer', 'peripheral nervous system neoplasm', 'amyotrophic lateral sclerosis', 'brain cancer', "Behcet's disease", "Graves' disease", 'muscle cancer', 'spinal cancer', 'thyroid cancer', 'rheumatoid arthritis', 'germ cell cancer', 'narcolepsy', 'pharynx cancer', 'meningioma', 'abdominal aortic aneurysm', 'osteoporosis', 'leprosy', 'multiple sclerosis', 'head and neck cancer', 'ankylosing spondylitis', 'bone cancer', 'mediastinal cancer', 'lung cancer', "Paget's disease of bone", 'thoracic aortic aneurysm']
# ...
# Diseases related to 'Williams Syndrome': ['celiac disease', 'hypertension', 'autistic disorder', 'hypothyroidism', 'attention deficit hyperactivity disorder']
# Diseases related to 'Cafe-au-Lait Spots': ['peripheral nervous system neoplasm', 'bone cancer', 'malignant glioma', 'germ cell cancer', 'brain cancer', 'skin cancer', 'adrenal gland cancer', 'vitiligo', 'head and neck cancer', 'penile cancer', 'duodenum cancer']
# Diseases related to 'Syncope, Vasovagal': ['epilepsy syndrome', 'pharynx cancer', 'dilated cardiomyopathy', 'head and neck cancer']
# Diseases related to 'Neck Pain': ['head and neck cancer', 'meningioma', 'pharynx cancer', 'psoriatic arthritis', 'bone cancer', 'rheumatoid arthritis', 'thyroid cancer', 'degenerative disc disease', 'osteoarthritis', 'psoriasis', 'ankylosing spondylitis', 'malignant glioma', 'germ cell cancer', 'migraine', 'spinal cancer', 'sarcoma']
# Diseases related to 'Hemifacial Spasm': ['germ cell cancer', 'meningioma', 'Creutzfeldt-Jakob disease', 'brain cancer', 'intracranial aneurysm', 'peripheral nervous system neoplasm', 'malignant glioma', 'hypertension']
# Diseases related to 'Blindness, Cortical': ['epilepsy syndrome', 'intracranial aneurysm', 'meningioma', 'Creutzfeldt-Jakob disease']
# Diseases related to 'Hot Flashes': ['breast cancer', 'uterine cancer', 'osteoporosis', 'uterine fibroid', 'prostate cancer']
# Diseases related to 'Aging, Premature': ['alcohol dependence', 'acquired immunodeficiency syndrome', 'vitiligo', "Alzheimer's disease", 'osteoporosis', 'idiopathic pulmonary fibrosis']
# Diseases related to 'Pseudophakia': ['refractive error', 'glaucoma', 'age related macular degeneration', "Fuchs' endothelial dystrophy"]
# Diseases related to 'Schnitzler Syndrome': ['rheumatoid arthritis']
# Diseases related to 'Neurobehavioral Manifestations': ['endogenous depression', "Alzheimer's disease", 'schizophrenia']
# Diseases related to 'Shoulder Pain': ['lung cancer', 'bone cancer', 'muscle cancer', 'rheumatoid arthritis', 'osteoarthritis', 'head and neck cancer', 'sarcoma', 'breast cancer', 'ankylosing spondylitis']
# Diseases related to 'Neurogenic Inflammation': ['multiple sclerosis', 'allergic rhinitis', 'asthma', 'psoriasis', 'pancreatitis', 'atopic dermatitis', 'migraine', "Alzheimer's disease", 'periodontitis']
# Diseases related to 'Chorea Gravidarum': []
# Diseases related to 'Hypersomnolence, Idiopathic': ['narcolepsy']
# Diseases related to 'Sleep Disorders, Circadian Rhythm': ['endogenous depression', "Alzheimer's disease", 'narcolepsy', 'attention deficit hyperactivity disorder', 'bipolar disorder']
# Diseases related to 'Jet Lag Syndrome': ['malaria']
# Diseases related to 'Sleep Apnea, Obstructive': ['coronary artery disease', 'allergic rhinitis', 'restless legs syndrome', 'hypertension', 'idiopathic pulmonary fibrosis', 'narcolepsy', 'pharynx cancer', 'chronic obstructive pulmonary disease', 'asthma', 'atherosclerosis', 'obesity', 'metabolic syndrome X']
# Diseases related to 'Sleep Apnea, Central': ['germ cell cancer', 'epilepsy syndrome', 'dilated cardiomyopathy', 'amyotrophic lateral sclerosis', 'chronic obstructive pulmonary disease']
# Diseases related to 'Nocturnal Paroxysmal Dystonia': ['epilepsy syndrome', 'restless legs syndrome']
# Diseases related to 'Night Terrors': ['panic disorder', 'epilepsy syndrome']
# Diseases related to 'Sleep Bruxism': ['endogenous depression']
# Diseases related to 'REM Sleep Behavior Disorder': ['narcolepsy', 'restless legs syndrome', "Parkinson's disease"]
# Diseases related to 'Sleep Paralysis': ['panic disorder', 'narcolepsy']
# Diseases related to 'Nocturnal Myoclonus Syndrome': ['narcolepsy', 'restless legs syndrome', "Parkinson's disease", 'attention deficit hyperactivity disorder', 'chronic kidney failure']
# Diseases related to 'Coma, Post-Head Injury': []
# Diseases related to 'Gait Disorders, Neurologic': ['amyotrophic lateral sclerosis', 'spinal cancer', "Parkinson's disease", 'Creutzfeldt-Jakob disease', 'osteoarthritis', 'malignant glioma', 'meningioma', 'leprosy', "Alzheimer's disease", 'multiple sclerosis', 'brain cancer']
# Diseases related to 'Gait Ataxia': ['Creutzfeldt-Jakob disease', 'multiple sclerosis', 'alcohol dependence', 'brain cancer', "Parkinson's disease", 'spinal cancer']
# Diseases related to 'Gait Apraxia': ["Parkinson's disease"]
# Diseases related to 'Amnesia, Transient Global': ['migraine', 'epilepsy syndrome']
# Diseases related to 'Alexia, Pure': []
# Diseases related to 'Prosopagnosia': ['autistic disorder', 'epilepsy syndrome', 'migraine', "Alzheimer's disease", 'schizophrenia']
# Diseases related to 'Apraxia, Ideomotor': ["Parkinson's disease", "Alzheimer's disease", 'amyotrophic lateral sclerosis']
# Diseases related to 'Postoperative Nausea and Vomiting': ['uterine cancer', 'breast cancer', 'nicotine dependence', 'brain cancer']
# Diseases related to 'Alcohol Withdrawal Seizures': ['alcohol dependence', 'epilepsy syndrome']
# Diseases related to 'Tics': ['Gilles de la Tourette syndrome', 'attention deficit hyperactivity disorder']
# Diseases related to 'Amnesia, Anterograde': ['brain cancer', 'germ cell cancer', 'intracranial aneurysm', 'epilepsy syndrome', 'malignant glioma']
# Diseases related to 'Paraparesis': ['abdominal aortic aneurysm', 'vascular cancer', 'sarcoma', 'germ cell cancer', 'mediastinal cancer', 'spinal cancer', 'skin cancer', 'meningioma', 'bone cancer', 'peripheral nervous system neoplasm', 'thoracic aortic aneurysm', 'kidney cancer']
# Diseases related to 'Paraparesis, Spastic': ['amyotrophic lateral sclerosis', "Alzheimer's disease", 'spinal cancer', 'multiple sclerosis']
# Diseases related to 'Myokymia': ['pharynx cancer', 'head and neck cancer', 'amyotrophic lateral sclerosis']
# Diseases related to 'Parasomnias': ['restless legs syndrome', 'epilepsy syndrome', 'narcolepsy']
# Diseases related to 'Fetal Weight': ['gestational diabetes', 'anemia']
# Diseases related to 'Spinocerebellar Ataxias': ['epilepsy syndrome', 'amyotrophic lateral sclerosis', "Parkinson's disease", 'age related macular degeneration', 'Creutzfeldt-Jakob disease', 'restless legs syndrome']
# Diseases related to 'Amaurosis Fugax': ['ocular cancer', 'systemic lupus erythematosus', 'glaucoma', 'migraine', 'atherosclerosis']
# Diseases related to 'Photophobia': ['refractive error', 'glaucoma', 'age related macular degeneration', 'migraine']
# Diseases related to 'Dyskinesias': ['schizophrenia', "Parkinson's disease"]
# Diseases related to 'Pseudobulbar Palsy': ['amyotrophic lateral sclerosis', 'epilepsy syndrome', 'multiple sclerosis']
# Diseases related to 'Neuromuscular Manifestations': []
# Diseases related to 'Somatosensory Disorders': ["Parkinson's disease", 'osteoarthritis', 'schizophrenia', 'autistic disorder', 'restless legs syndrome', 'panic disorder', 'migraine', 'spinal cancer', 'leprosy']
# Diseases related to 'Korsakoff Syndrome': ['alcohol dependence', 'brain cancer']
# Diseases related to 'Sleep Disorders, Intrinsic': ["Parkinson's disease", 'epilepsy syndrome']
# Diseases related to 'Dyssomnias': ['restless legs syndrome', 'breast cancer']
# Diseases related to 'Sleep Arousal Disorders': ['epilepsy syndrome']
# Diseases related to 'Sleep-Wake Transition Disorders': ['migraine', 'restless legs syndrome']
# Diseases related to 'REM Sleep Parasomnias': ['narcolepsy', "Parkinson's disease"]
# Diseases related to 'Urological Manifestations': []
# Diseases related to 'Flank Pain': ['germ cell cancer', 'peritoneum cancer', 'urinary bladder cancer', 'ureter cancer', 'abdominal aortic aneurysm', 'retroperitoneal cancer', 'kidney cancer', 'adrenal gland cancer', 'nephrolithiasis']
# Diseases related to 'Chills': ['melanoma', 'psoriasis', 'malaria']
# Diseases related to 'Insomnia, Fatal Familial': ['Creutzfeldt-Jakob disease']
# Diseases related to 'Hearing Loss': ['brain cancer', 'malignant glioma', 'ocular cancer', "Paget's disease of bone", 'bone cancer', 'cleft lip', 'germ cell cancer', 'hypothyroidism', 'pharynx cancer', 'otosclerosis', 'vitiligo', 'peripheral nervous system neoplasm', 'meningioma', 'head and neck cancer', 'testicular cancer']
# Diseases related to 'Metatarsalgia': ['osteoarthritis', 'rheumatoid arthritis', 'peripheral nervous system neoplasm']
# Diseases related to 'Mental Retardation, X-Linked': ['epilepsy syndrome', 'autistic disorder', 'anemia', 'cleft lip']
# Diseases related to 'Coffin-Lowry Syndrome': ['narcolepsy']
# Diseases related to 'Jaundice, Obstructive': ['bile duct cancer', 'sclerosing cholangitis', 'pancreatitis', 'peritoneum cancer', 'stomach cancer', 'primary biliary cirrhosis', 'sarcoma', 'muscle cancer', 'duodenum cancer', 'pancreatic cancer', 'anemia', 'liver cancer', 'kidney cancer', 'gallbladder cancer']
# Diseases related to 'Reticulocytosis': ['anemia', 'malaria']
# Diseases related to 'Hearing Loss, Unilateral': ['vitiligo', 'head and neck cancer', 'peripheral nervous system neoplasm', 'brain cancer', 'germ cell cancer']
# Diseases related to 'Hearing Loss, Mixed Conductive-Sensorineural': ['head and neck cancer', 'otosclerosis']
# Diseases related to 'Synkinesis': []
# Diseases related to 'Labor Pain': ['endogenous depression']
# Diseases related to 'Morning Sickness': []
# Diseases related to 'Overweight': ['hypertension', 'atherosclerosis', 'metabolic syndrome X', 'azoospermia', 'obesity', 'dental caries', 'gestational diabetes', 'polycystic ovary syndrome', 'type 2 diabetes mellitus']
# Diseases related to 'Mobility Limitation': ['osteoarthritis', 'atherosclerosis', 'ankylosing spondylitis', "Parkinson's disease", 'bone cancer', 'chronic obstructive pulmonary disease', 'osteoporosis', "Fuchs' endothelial dystrophy", 'multiple sclerosis']
# Diseases related to 'Neuralgia, Postherpetic': ['hematologic cancer']
# Diseases related to 'Glycogen Storage Disease Type IIb': ['dilated cardiomyopathy']
# Diseases related to 'Usher Syndromes': ['ocular cancer', 'age related macular degeneration']
# Diseases related to 'Nocturia': ["Parkinson's disease", 'prostate cancer', 'hypertension']
# Diseases related to 'Dysuria': ['prostate cancer', 'urinary bladder cancer', 'penile cancer', 'sarcoma', 'uterine fibroid', 'rectum cancer']
# Diseases related to 'Urinary Bladder, Overactive': ['type 2 diabetes mellitus', 'prostate cancer', 'urinary bladder cancer', "Parkinson's disease", 'multiple sclerosis', 'metabolic syndrome X']
# Diseases related to 'Urinary Incontinence, Urge': ['urinary bladder cancer', "Alzheimer's disease", 'multiple sclerosis']
# Diseases related to 'Prostatism': ['metabolic syndrome X', 'prostate cancer']
# Diseases related to 'Hypercalciuria': ['osteoporosis', 'nephrolithiasis']
# Diseases related to 'Opsoclonus-Myoclonus Syndrome': ['mediastinal cancer', 'germ cell cancer', 'adrenal gland cancer', 'lung cancer', 'ovarian cancer']
# Diseases related to 'Urinoma': ['nephrolithiasis', 'urinary bladder cancer', 'ureter cancer']
# Diseases related to 'Pain, Referred': ['abdominal aortic aneurysm', 'migraine']
# Diseases related to 'Stupor': ['endogenous depression', 'epilepsy syndrome', 'bipolar disorder']
# Diseases related to 'Lethargy': ['brain cancer', 'epilepsy syndrome']
# Diseases related to 'Acute Coronary Syndrome': ['chronic kidney failure', 'type 2 diabetes mellitus', 'endogenous depression', 'atherosclerosis', 'metabolic syndrome X', 'coronary artery disease']
# Diseases related to 'Deaf-Blind Disorders': []
# Diseases related to 'Livedo Reticularis': ['adrenal gland cancer', 'systemic lupus erythematosus', 'anemia', 'abdominal aortic aneurysm']
# Diseases related to 'Mevalonate Kinase Deficiency': ['Kawasaki disease']
# Diseases related to 'Systolic Murmurs': ['vascular cancer']
# Diseases related to 'Classical Lissencephalies and Subcortical Band Heterotopias': ['epilepsy syndrome']
# Diseases related to 'Neuroacanthocytosis': ['epilepsy syndrome']
# Diseases related to 'Orthostatic Intolerance': ['multiple sclerosis']
# Diseases related to 'Postural Orthostatic Tachycardia Syndrome': ['multiple sclerosis']
# Diseases related to 'Failed Back Surgery Syndrome': ['degenerative disc disease']
# Diseases related to 'Dysphonia': ['head and neck cancer', 'larynx cancer', 'asthma', 'melanoma', 'thyroid cancer', "Parkinson's disease", 'germ cell cancer', 'pharynx cancer']
# Diseases related to 'Purpura Fulminans': ['malaria']
# Diseases related to 'Sarcopenia': ['obesity', 'urinary bladder cancer', 'osteoporosis', 'metabolic syndrome X', 'liver cancer']
# Diseases related to 'Susac Syndrome': ['multiple sclerosis']
# Diseases related to 'Piriformis Muscle Syndrome': []
# Diseases related to 'Alien Hand Syndrome': ['Creutzfeldt-Jakob disease']
# Diseases related to 'Slit Ventricle Syndrome': []
# Diseases related to 'Obesity, Abdominal': ['type 2 diabetes mellitus', "Barrett's esophagus", 'esophageal cancer', 'polycystic ovary syndrome', 'metabolic syndrome X', 'atherosclerosis', 'obesity', 'hypertension']
# Diseases related to 'Renal Colic': ['abdominal aortic aneurysm', 'nephrolithiasis']
# Diseases related to 'Ideal Body Weight': ['stomach cancer', 'metabolic syndrome X', 'obesity']
# Diseases related to 'Primary Progressive Nonfluent Aphasia': ['Creutzfeldt-Jakob disease', "Alzheimer's disease"]
# Diseases related to 'Infantile Apparent Life-Threatening Event': []
# Diseases related to 'Post-Exercise Hypotension': ['hypertension']
# Diseases related to 'Striae Distensae': ['malignant glioma']
# Diseases related to 'Eye Pain': ['glaucoma', 'age related macular degeneration', 'refractive error', 'ocular cancer', 'bone cancer', 'germ cell cancer', 'melanoma']
# Diseases related to 'Necrolytic Migratory Erythema': ['pancreatic cancer', 'germ cell cancer']
# Diseases related to 'Nociceptive Pain': ['osteoarthritis', 'bone cancer', 'prostate cancer']
# Diseases related to 'Transient Tachypnea of the Newborn': []
# Diseases related to 'Tachypnea': ['chronic obstructive pulmonary disease']
# Diseases related to 'Visceral Pain': ['pancreatic cancer', 'pancreatitis']
# Diseases related to 'Chronic Pain': ['endogenous depression', 'rheumatoid arthritis', 'osteoarthritis', 'breast cancer', 'pancreatitis', 'nicotine dependence', 'ankylosing spondylitis', 'degenerative disc disease']
# Diseases related to 'Musculoskeletal Pain': ['osteoporosis', 'bone cancer', 'breast cancer', 'osteoarthritis']
# Diseases related to 'Mastodynia': ['breast cancer', 'prostate cancer']
# Diseases related to 'Pelvic Girdle Pain': []
# Diseases related to 'Breakthrough Pain': ['lung cancer', 'bone cancer']
# Diseases related to 'Lower Urinary Tract Symptoms': ['prostate cancer', 'urinary bladder cancer', 'multiple sclerosis', 'metabolic syndrome X', 'uterine fibroid']
# Diseases related to 'Anhedonia': ['nicotine dependence', 'endogenous depression', "Parkinson's disease", 'schizophrenia']
# Diseases related to 'Polydipsia': ['head and neck cancer', 'thyroid cancer', 'type 1 diabetes mellitus', 'adrenal gland cancer']
# Diseases related to 'Polydipsia, Psychogenic': ['schizophrenia']
# Diseases related to 'Acute Pain': ['coronary artery disease', 'osteoarthritis', 'anemia']
# Diseases related to 'Angina, Stable': ['coronary artery disease', 'atherosclerosis']
# Diseases related to 'Ophthalmoplegic Migraine': ['migraine', 'germ cell cancer']
# Diseases related to 'Pudendal Neuralgia': ['prostate cancer']
# Diseases related to 'Dyscalculia': []
# Diseases related to 'Alice in Wonderland Syndrome': ['migraine']
# Diseases related to 'Prodromal Symptoms': ['endogenous depression', 'schizophrenia', "Parkinson's disease", 'rheumatoid arthritis', 'amyotrophic lateral sclerosis', 'bipolar disorder', "Alzheimer's disease"]
# Diseases related to 'Pediatric Obesity': ['metabolic syndrome X', 'obesity']
# Diseases related to 'Myalgia': ['breast cancer']
# Diseases related to 'Hypertriglyceridemic Waist': ['metabolic syndrome X']
# Diseases related to 'Cerebrospinal Fluid Leak': ['meningioma', 'peripheral nervous system neoplasm', 'head and neck cancer', 'bone cancer', 'brain cancer', 'germ cell cancer', 'intracranial aneurysm']
# Diseases related to 'Benign Paroxysmal Positional Vertigo': ['migraine']
# Diseases related to 'Hyperlactatemia': []
# Diseases related to 'Allesthesia': []

# %% [markdown]
# Let's imagine an old patient with the symptom 'Constipation'. We are interested to check if there is probability that it is developing a 'lung cancer'.

# %%
# given the name of a symptom as input, finding all the diseases connected to it
diseases_list=[]
patient_symptom = 'Constipation'
print(f"Patient has experienced symptoms: {patient_symptom}","\n","Possible diseases:") 


diseases_sympt = diseases_per_symptom[patient_symptom]
for disease_name in diseases_sympt:
        diseases_list.append(disease_name)
        print(f"-{disease_name}")
# Out:
# Patient has experienced symptoms: Constipation
#  Possible diseases:
# -lung cancer
# -uterine fibroid
# -Crohn's disease
# -prostate cancer
# -uterine cancer
# -hypothyroidism
# -endogenous depression
# -ulcerative colitis
# -germ cell cancer
# -systemic scleroderma
# -retroperitoneal cancer
# -celiac disease
# -colon cancer
# -autistic disorder
# -stomach cancer
# -Parkinson's disease
# -rectum cancer
# -cervical cancer
# -ovarian cancer
# -multiple sclerosis
# -peritoneum cancer

# %% [markdown]
# Now, we are going to find which diseases may be connected to, and find which one has the lower compound number. For those, we are going to count the probability that this patient has this deasease depending on the symptoms computing the ratio between patient symptoms and the disease's list of symptoms.

# %%
# starting from the previous list of diseases, finding how many compounds there are to treat each of them
def count_compounds(G, diseases_list):
    disease_compound_counts = {}
    for disease_name in diseases_list:
        disease_id = next((node for node, data in G.nodes(data=True) if 'name' in data and data['name'] == disease_name and data['kind'] == 'Disease'), None)
        if disease_id is not None:
            predecessors = G.predecessors(disease_id)
            compound_count = sum(1 for predecessor in predecessors if G.nodes[predecessor].get('kind', '') == 'Compound')
            disease_compound_counts[disease_name] = compound_count
        else:
            print(f"Disease '{disease_name}' not found in the graph.")
            disease_compound_counts[disease_name] = 0
    
    sorted_disease_compound_counts = dict(sorted(disease_compound_counts.items(), key=lambda item: item[1]))
    
    return sorted_disease_compound_counts

sorted_disease_compound_counts = count_compounds(G, diseases_list)
print(sorted_disease_compound_counts)
# Out:
# {'uterine fibroid': 0, 'retroperitoneal cancer': 0, 'celiac disease': 0, 'rectum cancer': 0, 'peritoneum cancer': 0, 'cervical cancer': 1, 'hypothyroidism': 4, 'uterine cancer': 7, 'germ cell cancer': 7, "Crohn's disease": 8, 'autistic disorder': 8, 'colon cancer': 9, 'stomach cancer': 9, 'ovarian cancer': 10, 'endogenous depression': 15, 'ulcerative colitis': 16, 'lung cancer': 17, 'systemic scleroderma': 25, "Parkinson's disease": 28, 'prostate cancer': 30, 'multiple sclerosis': 33}

# %% [markdown]
# Fortunately, there are many compounds for lung cancer. Let's analyse which might be some possible solutions.

# %%
# given a disease name as input, finding the possible compounds that cure it
compounds = []
def find_compound_of_disease(G, disease_name):
    print(f"The patient was diagnosed with:'{disease_name}'","\n","Following there are the associated compounds:")
    disease_id = next((node for node, data in G.nodes(data=True) if 'name' in data and data['name'] == disease_name), None)
    if disease_id is not None:
        predecessors = G.predecessors(disease_id)
        for compound_id in predecessors:
            if 'kind' in G.nodes[compound_id] and G.nodes[compound_id]['kind'] == 'Compound':
                compound_name = G.nodes[compound_id].get('name', 'Unknown')
                compounds.append(compound_name)
        if len(compounds) > 0:
            for compound_name in compounds:
                print(f"-{compound_name}")
        else:
            print(f"No compound found for disease '{disease_name}'.")
    else:
        print(f"Disease '{disease_name}' not found in the graph.")
        
disease_name='lung cancer'
find_compound_of_disease(G, disease_name)
# Out:
# The patient was diagnosed with:'lung cancer'
#  Following there are the associated compounds:
# -Erlotinib
# -Methotrexate
# -Pemetrexed
# -Irinotecan
# -Doxorubicin
# -Gemcitabine
# -Cisplatin
# -Etoposide
# -Paclitaxel
# -Crizotinib
# -Docetaxel
# -Teniposide
# -Vinblastine
# -Gefitinib
# -Vinorelbine
# -Topotecan
# -Fentanyl

# %% [markdown]
# From this list, we should choose compounds that have less side effects possible.

# %%
# starting from the previous list of compounds, finding how many side effects each of them may create
def count_side_effects(G, compound_names):
    compound_side_effect_counts = {}
    for compound_name in compound_names:
        compound_id = next((node for node, data in G.nodes(data=True) if 'name' in data and data['name'] == compound_name and data['kind'] == 'Compound'), None)
        if compound_id is not None:
            successors = G.successors(compound_id)
            side_effect_count = sum(1 for side_effect in successors if G.nodes[side_effect].get('kind', '') == 'Side Effect')
            compound_side_effect_counts[compound_name] = side_effect_count
        else:
            print(f"Compound '{compound_name}' not found in the graph.")
            compound_side_effect_counts[compound_name] = 0
            
    sorted_compound_side_effect_counts = dict(sorted(compound_side_effect_counts.items(), key=lambda item: item[1]))
    
    return sorted_compound_side_effect_counts

sorted_compound_side_effect_counts = count_side_effects(G, compounds)
print(sorted_compound_side_effect_counts)
# Out:
# {'Vinblastine': 59, 'Teniposide': 70, 'Crizotinib': 99, 'Topotecan': 111, 'Pemetrexed': 124, 'Gefitinib': 126, 'Erlotinib': 152, 'Etoposide': 153, 'Vinorelbine': 164, 'Cisplatin': 169, 'Irinotecan': 177, 'Gemcitabine': 189, 'Docetaxel': 297, 'Methotrexate': 319, 'Paclitaxel': 442, 'Doxorubicin': 511, 'Fentanyl': 521}

# %% [markdown]
# From these results, we conclude that an optimal solution is to prescribe Vinblastine.
